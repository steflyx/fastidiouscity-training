# %% [markdown]
# # Scraping Statements from Politifact
# This notebook is used to gather statements and related info from Politifact. My aim is to create a big enough dataset to train a classifier to recognize whether a sentence is worth fact-checking or not.

# %% [markdown]
# ## Imports

# %%
import numpy as np
from bs4 import BeautifulSoup
import requests
import time
import json
import pandas as pd
import datetime

# %% [markdown]
# ## Crawling Politifact
# First, I will retrieve web pages from Politifact containing statements from various politicians.

# %%
page_start = 1
last_page = 2000
seconds_pause = 2

for page_number in range(page_start, last_page):
    try:
        #Gather the html data
        page_url = 'https://www.politifact.com/api/factchecks/?page={}'.format(page_number)
        response = requests.get(page_url)
        
        #Save html page in a file
        with open("html_pages/{}.html".format(page_number), "w", encoding="utf-8") as f:
            f.write(response.text)

        #Pause for two seconds
        print('scraped page {}'.format(page_number))
        time.sleep(seconds_pause)
        
    except Exception as e:
        print('\nfailed to scrape page {}\n{}\n'.format(page_number, e))
# Out:
# scraped page 1691
# scraped page 1692
# scraped page 1693
# scraped page 1694
# scraped page 1695
# scraped page 1696
# scraped page 1697
# scraped page 1698
# scraped page 1699
# scraped page 1700
# scraped page 1701
# scraped page 1702
# scraped page 1703
# scraped page 1704
# scraped page 1705
# scraped page 1706
# scraped page 1707
# scraped page 1708
# scraped page 1709
# scraped page 1710
# scraped page 1711
# scraped page 1712
# scraped page 1713
# scraped page 1714
# scraped page 1715
# scraped page 1716
# scraped page 1717
# scraped page 1718
# scraped page 1719
# scraped page 1720
# scraped page 1721
# scraped page 1722
# scraped page 1723
# scraped page 1724
# scraped page 1725
# scraped page 1726
# scraped page 1727
# scraped page 1728
# scraped page 1729
# scraped page 1730
# scraped page 1731
# scraped page 1732
# scraped page 1733
# scraped page 1734
# scraped page 1735
# scraped page 1736
# scraped page 1737
# scraped page 1738
# scraped page 1739
# scraped page 1740
# scraped page 1741
# scraped page 1742
# scraped page 1743
# scraped page 1744
# scraped page 1745
# scraped page 1746
# scraped page 1747
# scraped page 1748
# scraped page 1749
# scraped page 1750
# scraped page 1751
# scraped page 1752
# scraped page 1753
# scraped page 1754
# scraped page 1755
# scraped page 1756
# scraped page 1757
# scraped page 1758
# scraped page 1759
# scraped page 1760
# scraped page 1761
# scraped page 1762
# scraped page 1763
# scraped page 1764
# scraped page 1765
# scraped page 1766
# scraped page 1767
# scraped page 1768
# scraped page 1769
# scraped page 1770
# scraped page 1771
# scraped page 1772
# scraped page 1773
# scraped page 1774
# scraped page 1775
# scraped page 1776
# scraped page 1777
# scraped page 1778
# scraped page 1779
# scraped page 1780
# scraped page 1781
# scraped page 1782
# scraped page 1783
# scraped page 1784
# scraped page 1785
# scraped page 1786
# scraped page 1787
# scraped page 1788
# scraped page 1789
# scraped page 1790
# scraped page 1791
# scraped page 1792
# scraped page 1793
# scraped page 1794
# scraped page 1795
# scraped page 1796
# scraped page 1797
# scraped page 1798
# scraped page 1799
# scraped page 1800
# scraped page 1801
# scraped page 1802
# scraped page 1803
# scraped page 1804
# scraped page 1805
# scraped page 1806
# scraped page 1807
# scraped page 1808
# scraped page 1809
# scraped page 1810
# scraped page 1811
# scraped page 1812
# scraped page 1813
# scraped page 1814
# scraped page 1815
# scraped page 1816
# scraped page 1817
# scraped page 1818
# scraped page 1819
# scraped page 1820
# scraped page 1821
# scraped page 1822
# scraped page 1823
# scraped page 1824
# scraped page 1825
# scraped page 1826
# scraped page 1827
# scraped page 1828
# scraped page 1829
# scraped page 1830
# scraped page 1831
# scraped page 1832
# scraped page 1833
# scraped page 1834
# scraped page 1835
# scraped page 1836
# scraped page 1837
# scraped page 1838
# scraped page 1839
# scraped page 1840
# scraped page 1841
# scraped page 1842
# scraped page 1843
# scraped page 1844
# scraped page 1845
# scraped page 1846
# scraped page 1847
# scraped page 1848
# scraped page 1849
# scraped page 1850
# scraped page 1851
# scraped page 1852
# scraped page 1853
# scraped page 1854
# scraped page 1855
# scraped page 1856
# scraped page 1857
# scraped page 1858
# scraped page 1859
# scraped page 1860
# scraped page 1861
# scraped page 1862
# scraped page 1863
# scraped page 1864
# scraped page 1865
# scraped page 1866
# scraped page 1867
# scraped page 1868
# scraped page 1869
# scraped page 1870
# scraped page 1871
# scraped page 1872
# scraped page 1873
# scraped page 1874
# scraped page 1875
# scraped page 1876
# scraped page 1877
# scraped page 1878
# scraped page 1879
# scraped page 1880
# scraped page 1881
# scraped page 1882
# scraped page 1883
# scraped page 1884
# scraped page 1885
# scraped page 1886
# scraped page 1887
# scraped page 1888
# scraped page 1889
# scraped page 1890
# scraped page 1891
# scraped page 1892
# scraped page 1893
# scraped page 1894
# scraped page 1895
# scraped page 1896
# scraped page 1897
# scraped page 1898
# scraped page 1899
# scraped page 1900
# scraped page 1901
# scraped page 1902
# scraped page 1903
# scraped page 1904
# scraped page 1905
# scraped page 1906
# scraped page 1907
# scraped page 1908
# scraped page 1909
# scraped page 1910
# scraped page 1911
# scraped page 1912
# scraped page 1913
# scraped page 1914
# scraped page 1915
# scraped page 1916
# scraped page 1917
# scraped page 1918
# scraped page 1919
# scraped page 1920
# scraped page 1921
# scraped page 1922
# scraped page 1923
# scraped page 1924
# scraped page 1925
# scraped page 1926
# scraped page 1927
# scraped page 1928
# scraped page 1929
# scraped page 1930
# scraped page 1931
# scraped page 1932
# scraped page 1933
# scraped page 1934
# scraped page 1935
# scraped page 1936
# scraped page 1937
# scraped page 1938
# scraped page 1939
# scraped page 1940
# scraped page 1941
# scraped page 1942
# scraped page 1943
# scraped page 1944
# scraped page 1945
# scraped page 1946
# scraped page 1947
# scraped page 1948
# scraped page 1949
# scraped page 1950
# scraped page 1951
# scraped page 1952
# scraped page 1953
# scraped page 1954
# scraped page 1955
# scraped page 1956
# scraped page 1957
# scraped page 1958
# scraped page 1959
# scraped page 1960
# scraped page 1961
# scraped page 1962
# scraped page 1963
# scraped page 1964
# scraped page 1965
# scraped page 1966
# scraped page 1967
# scraped page 1968
# scraped page 1969
# scraped page 1970
# scraped page 1971
# scraped page 1972
# scraped page 1973
# scraped page 1974
# scraped page 1975
# scraped page 1976
# scraped page 1977
# scraped page 1978
# scraped page 1979
# scraped page 1980
# scraped page 1981
# scraped page 1982
# scraped page 1983
# scraped page 1984
# scraped page 1985
# scraped page 1986
# scraped page 1987
# scraped page 1988
# scraped page 1989
# scraped page 1990
# scraped page 1991
# scraped page 1992
# scraped page 1993
# scraped page 1994
# scraped page 1995
# scraped page 1996
# scraped page 1997
# scraped page 1998
# scraped page 1999

# %% [markdown]
# ## Retrieve statements
# The data right now is in a JSON-like form, but is not usable because of numerous non-utf8 symbols that cause the various json and pandas libraries to crash. Therefore, I created my own functions to handle the problem, in order to create an array that will contain all the statements from Politifact, together with related author, targets and truthfulness value.

# %%
#Utility functions for handling Politifact pages

#Removes "Says" from the beginning of the sentence. Replaces weird characters
def clean_sentence(sentence):
    
    sentence = sentence.replace("”", '"')
    sentence = sentence.replace("’", "'")
    sentence = sentence.replace("“", '"')
    if sentence[:5] == "Says ":
        sentence = sentence[5:]
    
    return sentence

#Retrieves the full name of the author
def clean_author(author):
    return author.split('"full_name":"')[1].split('","first_name"')[0]

#Retrieves the name(s) of the targets
def clean_target(target):
    
    num_targets = target.count("full_name")
    
    #There might be no target
    if num_targets == 0:
        return []
    
    #Return targets inside an array
    targets = target.split('"full_name":"')[1:]
    result = []
    for t in targets:
        result.append(t.split('","first_name"')[0])
    return result

# %%
statements = []
for num_page in range(1,1830):

    # Load a saved html
    print("Analyzing page nr ", num_page)
    with open("html_pages/{}.html".format(num_page), "r", encoding="utf-8") as f:
            html = f.read()

    #Remove the header
    json_rows = html.split('{"id":')[1:]

    #Retrieve the interesting information
    for row in json_rows:
        statement = {}

        sentence = row.split('"statement":"')[1].split('","ruling_slug')[0]
        author = row.split('"speaker":')[1].split(',"targets"')[0]
        target = row.split('"targets":')[1].split(',"statement"')[0]
        ruling = row.split('"ruling_slug":"')[1].split('","publication_date":')[0]
        date = row.split('"publication_date":"')[1].split('T')[0]

        statement['sentence'] = clean_sentence(sentence)
        statement['author'] = clean_author(author)
        statement['target'] = clean_target(target)
        statement['ruling'] = ruling
        statement['date'] = date

        statements.append(statement)
        
print("We gathered: {0} statements".format(len(statements)))
# Out:
# Analyzing page nr  1
# Analyzing page nr  2
# Analyzing page nr  3
# Analyzing page nr  4
# Analyzing page nr  5
# Analyzing page nr  6
# Analyzing page nr  7
# Analyzing page nr  8
# Analyzing page nr  9
# Analyzing page nr  10
# Analyzing page nr  11
# Analyzing page nr  12
# Analyzing page nr  13
# Analyzing page nr  14
# Analyzing page nr  15
# Analyzing page nr  16
# Analyzing page nr  17
# Analyzing page nr  18
# Analyzing page nr  19
# Analyzing page nr  20
# Analyzing page nr  21
# Analyzing page nr  22
# Analyzing page nr  23
# Analyzing page nr  24
# Analyzing page nr  25
# Analyzing page nr  26
# Analyzing page nr  27
# Analyzing page nr  28
# Analyzing page nr  29
# Analyzing page nr  30
# Analyzing page nr  31
# Analyzing page nr  32
# Analyzing page nr  33
# Analyzing page nr  34
# Analyzing page nr  35
# Analyzing page nr  36
# Analyzing page nr  37
# Analyzing page nr  38
# Analyzing page nr  39
# Analyzing page nr  40
# Analyzing page nr  41
# Analyzing page nr  42
# Analyzing page nr  43
# Analyzing page nr  44
# Analyzing page nr  45
# Analyzing page nr  46
# Analyzing page nr  47
# Analyzing page nr  48
# Analyzing page nr  49
# Analyzing page nr  50
# Analyzing page nr  51
# Analyzing page nr  52
# Analyzing page nr  53
# Analyzing page nr  54
# Analyzing page nr  55
# Analyzing page nr  56
# Analyzing page nr  57
# Analyzing page nr  58
# Analyzing page nr  59
# Analyzing page nr  60
# Analyzing page nr  61
# Analyzing page nr  62
# Analyzing page nr  63
# Analyzing page nr  64
# Analyzing page nr  65
# Analyzing page nr  66
# Analyzing page nr  67
# Analyzing page nr  68
# Analyzing page nr  69
# Analyzing page nr  70
# Analyzing page nr  71
# Analyzing page nr  72
# Analyzing page nr  73
# Analyzing page nr  74
# Analyzing page nr  75
# Analyzing page nr  76
# Analyzing page nr  77
# Analyzing page nr  78
# Analyzing page nr  79
# Analyzing page nr  80
# Analyzing page nr  81
# Analyzing page nr  82
# Analyzing page nr  83
# Analyzing page nr  84
# Analyzing page nr  85
# Analyzing page nr  86
# Analyzing page nr  87
# Analyzing page nr  88
# Analyzing page nr  89
# Analyzing page nr  90
# Analyzing page nr  91
# Analyzing page nr  92
# Analyzing page nr  93
# Analyzing page nr  94
# Analyzing page nr  95
# Analyzing page nr  96
# Analyzing page nr  97
# Analyzing page nr  98
# Analyzing page nr  99
# Analyzing page nr  100
# Analyzing page nr  101
# Analyzing page nr  102
# Analyzing page nr  103
# Analyzing page nr  104
# Analyzing page nr  105
# Analyzing page nr  106
# Analyzing page nr  107
# Analyzing page nr  108
# Analyzing page nr  109
# Analyzing page nr  110
# Analyzing page nr  111
# Analyzing page nr  112
# Analyzing page nr  113
# Analyzing page nr  114
# Analyzing page nr  115
# Analyzing page nr  116
# Analyzing page nr  117
# Analyzing page nr  118
# Analyzing page nr  119
# Analyzing page nr  120
# Analyzing page nr  121
# Analyzing page nr  122
# Analyzing page nr  123
# Analyzing page nr  124
# Analyzing page nr  125
# Analyzing page nr  126
# Analyzing page nr  127
# Analyzing page nr  128
# Analyzing page nr  129
# Analyzing page nr  130
# Analyzing page nr  131
# Analyzing page nr  132
# Analyzing page nr  133
# Analyzing page nr  134
# Analyzing page nr  135
# Analyzing page nr  136
# Analyzing page nr  137
# Analyzing page nr  138
# Analyzing page nr  139
# Analyzing page nr  140
# Analyzing page nr  141
# Analyzing page nr  142
# Analyzing page nr  143
# Analyzing page nr  144
# Analyzing page nr  145
# Analyzing page nr  146
# Analyzing page nr  147
# Analyzing page nr  148
# Analyzing page nr  149
# Analyzing page nr  150
# Analyzing page nr  151
# Analyzing page nr  152
# Analyzing page nr  153
# Analyzing page nr  154
# Analyzing page nr  155
# Analyzing page nr  156
# Analyzing page nr  157
# Analyzing page nr  158
# Analyzing page nr  159
# Analyzing page nr  160
# Analyzing page nr  161
# Analyzing page nr  162
# Analyzing page nr  163
# Analyzing page nr  164
# Analyzing page nr  165
# Analyzing page nr  166
# Analyzing page nr  167
# Analyzing page nr  168
# Analyzing page nr  169
# Analyzing page nr  170
# Analyzing page nr  171
# Analyzing page nr  172
# Analyzing page nr  173
# Analyzing page nr  174
# Analyzing page nr  175
# Analyzing page nr  176
# Analyzing page nr  177
# Analyzing page nr  178
# Analyzing page nr  179
# Analyzing page nr  180
# Analyzing page nr  181
# Analyzing page nr  182
# Analyzing page nr  183
# Analyzing page nr  184
# Analyzing page nr  185
# Analyzing page nr  186
# Analyzing page nr  187
# Analyzing page nr  188
# Analyzing page nr  189
# Analyzing page nr  190
# Analyzing page nr  191
# Analyzing page nr  192
# Analyzing page nr  193
# Analyzing page nr  194
# Analyzing page nr  195
# Analyzing page nr  196
# Analyzing page nr  197
# Analyzing page nr  198
# Analyzing page nr  199
# Analyzing page nr  200
# Analyzing page nr  201
# Analyzing page nr  202
# Analyzing page nr  203
# Analyzing page nr  204
# Analyzing page nr  205
# Analyzing page nr  206
# Analyzing page nr  207
# Analyzing page nr  208
# Analyzing page nr  209
# Analyzing page nr  210
# Analyzing page nr  211
# Analyzing page nr  212
# Analyzing page nr  213
# Analyzing page nr  214
# Analyzing page nr  215
# Analyzing page nr  216
# Analyzing page nr  217
# Analyzing page nr  218
# Analyzing page nr  219
# Analyzing page nr  220
# Analyzing page nr  221
# Analyzing page nr  222
# Analyzing page nr  223
# Analyzing page nr  224
# Analyzing page nr  225
# Analyzing page nr  226
# Analyzing page nr  227
# Analyzing page nr  228
# Analyzing page nr  229
# Analyzing page nr  230
# Analyzing page nr  231
# Analyzing page nr  232
# Analyzing page nr  233
# Analyzing page nr  234
# Analyzing page nr  235
# Analyzing page nr  236
# Analyzing page nr  237
# Analyzing page nr  238
# Analyzing page nr  239
# Analyzing page nr  240
# Analyzing page nr  241
# Analyzing page nr  242
# Analyzing page nr  243
# Analyzing page nr  244
# Analyzing page nr  245
# Analyzing page nr  246
# Analyzing page nr  247
# Analyzing page nr  248
# Analyzing page nr  249
# Analyzing page nr  250
# Analyzing page nr  251
# Analyzing page nr  252
# Analyzing page nr  253
# Analyzing page nr  254
# Analyzing page nr  255
# Analyzing page nr  256
# Analyzing page nr  257
# Analyzing page nr  258
# Analyzing page nr  259
# Analyzing page nr  260
# Analyzing page nr  261
# Analyzing page nr  262
# Analyzing page nr  263
# Analyzing page nr  264
# Analyzing page nr  265
# Analyzing page nr  266
# Analyzing page nr  267
# Analyzing page nr  268
# Analyzing page nr  269
# Analyzing page nr  270
# Analyzing page nr  271
# Analyzing page nr  272
# Analyzing page nr  273
# Analyzing page nr  274
# Analyzing page nr  275
# Analyzing page nr  276
# Analyzing page nr  277
# Analyzing page nr  278
# Analyzing page nr  279
# Analyzing page nr  280
# Analyzing page nr  281
# Analyzing page nr  282
# Analyzing page nr  283
# Analyzing page nr  284
# Analyzing page nr  285
# Analyzing page nr  286
# Analyzing page nr  287
# Analyzing page nr  288
# Analyzing page nr  289
# Analyzing page nr  290
# Analyzing page nr  291
# Analyzing page nr  292
# Analyzing page nr  293
# Analyzing page nr  294
# Analyzing page nr  295
# Analyzing page nr  296
# Analyzing page nr  297
# Analyzing page nr  298
# Analyzing page nr  299
# Analyzing page nr  300
# Analyzing page nr  301
# Analyzing page nr  302
# Analyzing page nr  303
# Analyzing page nr  304
# Analyzing page nr  305
# Analyzing page nr  306
# Analyzing page nr  307
# Analyzing page nr  308
# Analyzing page nr  309
# Analyzing page nr  310
# Analyzing page nr  311
# Analyzing page nr  312
# Analyzing page nr  313
# Analyzing page nr  314
# Analyzing page nr  315
# Analyzing page nr  316
# Analyzing page nr  317
# Analyzing page nr  318
# Analyzing page nr  319
# Analyzing page nr  320
# Analyzing page nr  321
# Analyzing page nr  322
# Analyzing page nr  323
# Analyzing page nr  324
# Analyzing page nr  325
# Analyzing page nr  326
# Analyzing page nr  327
# Analyzing page nr  328
# Analyzing page nr  329
# Analyzing page nr  330
# Analyzing page nr  331
# Analyzing page nr  332
# Analyzing page nr  333
# Analyzing page nr  334
# Analyzing page nr  335
# Analyzing page nr  336
# Analyzing page nr  337
# Analyzing page nr  338
# Analyzing page nr  339
# Analyzing page nr  340
# Analyzing page nr  341
# Analyzing page nr  342
# Analyzing page nr  343
# Analyzing page nr  344
# Analyzing page nr  345
# Analyzing page nr  346
# Analyzing page nr  347
# Analyzing page nr  348
# Analyzing page nr  349
# Analyzing page nr  350
# Analyzing page nr  351
# Analyzing page nr  352
# Analyzing page nr  353
# Analyzing page nr  354
# Analyzing page nr  355
# Analyzing page nr  356
# Analyzing page nr  357
# Analyzing page nr  358
# Analyzing page nr  359
# Analyzing page nr  360
# Analyzing page nr  361
# Analyzing page nr  362
# Analyzing page nr  363
# Analyzing page nr  364
# Analyzing page nr  365
# Analyzing page nr  366
# Analyzing page nr  367
# Analyzing page nr  368
# Analyzing page nr  369
# Analyzing page nr  370
# Analyzing page nr  371
# Analyzing page nr  372
# Analyzing page nr  373
# Analyzing page nr  374
# Analyzing page nr  375
# Analyzing page nr  376
# Analyzing page nr  377
# Analyzing page nr  378
# Analyzing page nr  379
# Analyzing page nr  380
# Analyzing page nr  381
# Analyzing page nr  382
# Analyzing page nr  383
# Analyzing page nr  384
# Analyzing page nr  385
# Analyzing page nr  386
# Analyzing page nr  387
# Analyzing page nr  388
# Analyzing page nr  389
# Analyzing page nr  390
# Analyzing page nr  391
# Analyzing page nr  392
# Analyzing page nr  393
# Analyzing page nr  394
# Analyzing page nr  395
# Analyzing page nr  396
# Analyzing page nr  397
# Analyzing page nr  398
# Analyzing page nr  399
# Analyzing page nr  400
# Analyzing page nr  401
# Analyzing page nr  402
# Analyzing page nr  403
# Analyzing page nr  404
# Analyzing page nr  405
# Analyzing page nr  406
# Analyzing page nr  407
# Analyzing page nr  408
# Analyzing page nr  409
# Analyzing page nr  410
# Analyzing page nr  411
# Analyzing page nr  412
# Analyzing page nr  413
# Analyzing page nr  414
# Analyzing page nr  415
# Analyzing page nr  416
# Analyzing page nr  417
# Analyzing page nr  418
# Analyzing page nr  419
# Analyzing page nr  420
# Analyzing page nr  421
# Analyzing page nr  422
# Analyzing page nr  423
# Analyzing page nr  424
# Analyzing page nr  425
# Analyzing page nr  426
# Analyzing page nr  427
# Analyzing page nr  428
# Analyzing page nr  429
# Analyzing page nr  430
# Analyzing page nr  431
# Analyzing page nr  432
# Analyzing page nr  433
# Analyzing page nr  434
# Analyzing page nr  435
# Analyzing page nr  436
# Analyzing page nr  437
# Analyzing page nr  438
# Analyzing page nr  439
# Analyzing page nr  440
# Analyzing page nr  441
# Analyzing page nr  442
# Analyzing page nr  443
# Analyzing page nr  444
# Analyzing page nr  445
# Analyzing page nr  446
# Analyzing page nr  447
# Analyzing page nr  448
# Analyzing page nr  449
# Analyzing page nr  450
# Analyzing page nr  451
# Analyzing page nr  452
# Analyzing page nr  453
# Analyzing page nr  454
# Analyzing page nr  455
# Analyzing page nr  456
# Analyzing page nr  457
# Analyzing page nr  458
# Analyzing page nr  459
# Analyzing page nr  460
# Analyzing page nr  461
# Analyzing page nr  462
# Analyzing page nr  463
# Analyzing page nr  464
# Analyzing page nr  465
# Analyzing page nr  466
# Analyzing page nr  467
# Analyzing page nr  468
# Analyzing page nr  469
# Analyzing page nr  470
# Analyzing page nr  471
# Analyzing page nr  472
# Analyzing page nr  473
# Analyzing page nr  474
# Analyzing page nr  475
# Analyzing page nr  476
# Analyzing page nr  477
# Analyzing page nr  478
# Analyzing page nr  479
# Analyzing page nr  480
# Analyzing page nr  481
# Analyzing page nr  482
# Analyzing page nr  483
# Analyzing page nr  484
# Analyzing page nr  485
# Analyzing page nr  486
# Analyzing page nr  487
# Analyzing page nr  488
# Analyzing page nr  489
# Analyzing page nr  490
# Analyzing page nr  491
# Analyzing page nr  492
# Analyzing page nr  493
# Analyzing page nr  494
# Analyzing page nr  495
# Analyzing page nr  496
# Analyzing page nr  497
# Analyzing page nr  498
# Analyzing page nr  499
# Analyzing page nr  500
# Analyzing page nr  501
# Analyzing page nr  502
# Analyzing page nr  503
# Analyzing page nr  504
# Analyzing page nr  505
# Analyzing page nr  506
# Analyzing page nr  507
# Analyzing page nr  508
# Analyzing page nr  509
# Analyzing page nr  510
# Analyzing page nr  511
# Analyzing page nr  512
# Analyzing page nr  513
# Analyzing page nr  514
# Analyzing page nr  515
# Analyzing page nr  516
# Analyzing page nr  517
# Analyzing page nr  518
# Analyzing page nr  519
# Analyzing page nr  520
# Analyzing page nr  521
# Analyzing page nr  522
# Analyzing page nr  523
# Analyzing page nr  524
# Analyzing page nr  525
# Analyzing page nr  526
# Analyzing page nr  527
# Analyzing page nr  528
# Analyzing page nr  529
# Analyzing page nr  530
# Analyzing page nr  531
# Analyzing page nr  532
# Analyzing page nr  533
# Analyzing page nr  534
# Analyzing page nr  535
# Analyzing page nr  536
# Analyzing page nr  537
# Analyzing page nr  538
# Analyzing page nr  539
# Analyzing page nr  540
# Analyzing page nr  541
# Analyzing page nr  542
# Analyzing page nr  543
# Analyzing page nr  544
# Analyzing page nr  545
# Analyzing page nr  546
# Analyzing page nr  547
# Analyzing page nr  548
# Analyzing page nr  549
# Analyzing page nr  550
# Analyzing page nr  551
# Analyzing page nr  552
# Analyzing page nr  553
# Analyzing page nr  554
# Analyzing page nr  555
# Analyzing page nr  556
# Analyzing page nr  557
# Analyzing page nr  558
# Analyzing page nr  559
# Analyzing page nr  560
# Analyzing page nr  561
# Analyzing page nr  562
# Analyzing page nr  563
# Analyzing page nr  564
# Analyzing page nr  565
# Analyzing page nr  566
# Analyzing page nr  567
# Analyzing page nr  568
# Analyzing page nr  569
# Analyzing page nr  570
# Analyzing page nr  571
# Analyzing page nr  572
# Analyzing page nr  573
# Analyzing page nr  574
# Analyzing page nr  575
# Analyzing page nr  576
# Analyzing page nr  577
# Analyzing page nr  578
# Analyzing page nr  579
# Analyzing page nr  580
# Analyzing page nr  581
# Analyzing page nr  582
# Analyzing page nr  583
# Analyzing page nr  584
# Analyzing page nr  585
# Analyzing page nr  586
# Analyzing page nr  587
# Analyzing page nr  588
# Analyzing page nr  589
# Analyzing page nr  590
# Analyzing page nr  591
# Analyzing page nr  592
# Analyzing page nr  593
# Analyzing page nr  594
# Analyzing page nr  595
# Analyzing page nr  596
# Analyzing page nr  597
# Analyzing page nr  598
# Analyzing page nr  599
# Analyzing page nr  600
# Analyzing page nr  601
# Analyzing page nr  602
# Analyzing page nr  603
# Analyzing page nr  604
# Analyzing page nr  605
# Analyzing page nr  606
# Analyzing page nr  607
# Analyzing page nr  608
# Analyzing page nr  609
# Analyzing page nr  610
# Analyzing page nr  611
# Analyzing page nr  612
# Analyzing page nr  613
# Analyzing page nr  614
# Analyzing page nr  615
# Analyzing page nr  616
# Analyzing page nr  617
# Analyzing page nr  618
# Analyzing page nr  619
# Analyzing page nr  620
# Analyzing page nr  621
# Analyzing page nr  622
# Analyzing page nr  623
# Analyzing page nr  624
# Analyzing page nr  625
# Analyzing page nr  626
# Analyzing page nr  627
# Analyzing page nr  628
# Analyzing page nr  629
# Analyzing page nr  630
# Analyzing page nr  631
# Analyzing page nr  632
# Analyzing page nr  633
# Analyzing page nr  634
# Analyzing page nr  635
# Analyzing page nr  636
# Analyzing page nr  637
# Analyzing page nr  638
# Analyzing page nr  639
# Analyzing page nr  640
# Analyzing page nr  641
# Analyzing page nr  642
# Analyzing page nr  643
# Analyzing page nr  644
# Analyzing page nr  645
# Analyzing page nr  646
# Analyzing page nr  647
# Analyzing page nr  648
# Analyzing page nr  649
# Analyzing page nr  650
# Analyzing page nr  651
# Analyzing page nr  652
# Analyzing page nr  653
# Analyzing page nr  654
# Analyzing page nr  655
# Analyzing page nr  656
# Analyzing page nr  657
# Analyzing page nr  658
# Analyzing page nr  659
# Analyzing page nr  660
# Analyzing page nr  661
# Analyzing page nr  662
# Analyzing page nr  663
# Analyzing page nr  664
# Analyzing page nr  665
# Analyzing page nr  666
# Analyzing page nr  667
# Analyzing page nr  668
# Analyzing page nr  669
# Analyzing page nr  670
# Analyzing page nr  671
# Analyzing page nr  672
# Analyzing page nr  673
# Analyzing page nr  674
# Analyzing page nr  675
# Analyzing page nr  676
# Analyzing page nr  677
# Analyzing page nr  678
# Analyzing page nr  679
# Analyzing page nr  680
# Analyzing page nr  681
# Analyzing page nr  682
# Analyzing page nr  683
# Analyzing page nr  684
# Analyzing page nr  685
# Analyzing page nr  686
# Analyzing page nr  687
# Analyzing page nr  688
# Analyzing page nr  689
# Analyzing page nr  690
# Analyzing page nr  691
# Analyzing page nr  692
# Analyzing page nr  693
# Analyzing page nr  694
# Analyzing page nr  695
# Analyzing page nr  696
# Analyzing page nr  697
# Analyzing page nr  698
# Analyzing page nr  699
# Analyzing page nr  700
# Analyzing page nr  701
# Analyzing page nr  702
# Analyzing page nr  703
# Analyzing page nr  704
# Analyzing page nr  705
# Analyzing page nr  706
# Analyzing page nr  707
# Analyzing page nr  708
# Analyzing page nr  709
# Analyzing page nr  710
# Analyzing page nr  711
# Analyzing page nr  712
# Analyzing page nr  713
# Analyzing page nr  714
# Analyzing page nr  715
# Analyzing page nr  716
# Analyzing page nr  717
# Analyzing page nr  718
# Analyzing page nr  719
# Analyzing page nr  720
# Analyzing page nr  721
# Analyzing page nr  722
# Analyzing page nr  723
# Analyzing page nr  724
# Analyzing page nr  725
# Analyzing page nr  726
# Analyzing page nr  727
# Analyzing page nr  728
# Analyzing page nr  729
# Analyzing page nr  730
# Analyzing page nr  731
# Analyzing page nr  732
# Analyzing page nr  733
# Analyzing page nr  734
# Analyzing page nr  735
# Analyzing page nr  736
# Analyzing page nr  737
# Analyzing page nr  738
# Analyzing page nr  739
# Analyzing page nr  740
# Analyzing page nr  741
# Analyzing page nr  742
# Analyzing page nr  743
# Analyzing page nr  744
# Analyzing page nr  745
# Analyzing page nr  746
# Analyzing page nr  747
# Analyzing page nr  748
# Analyzing page nr  749
# Analyzing page nr  750
# Analyzing page nr  751
# Analyzing page nr  752
# Analyzing page nr  753
# Analyzing page nr  754
# Analyzing page nr  755
# Analyzing page nr  756
# Analyzing page nr  757
# Analyzing page nr  758
# Analyzing page nr  759
# Analyzing page nr  760
# Analyzing page nr  761
# Analyzing page nr  762
# Analyzing page nr  763
# Analyzing page nr  764
# Analyzing page nr  765
# Analyzing page nr  766
# Analyzing page nr  767
# Analyzing page nr  768
# Analyzing page nr  769
# Analyzing page nr  770
# Analyzing page nr  771
# Analyzing page nr  772
# Analyzing page nr  773
# Analyzing page nr  774
# Analyzing page nr  775
# Analyzing page nr  776
# Analyzing page nr  777
# Analyzing page nr  778
# Analyzing page nr  779
# Analyzing page nr  780
# Analyzing page nr  781
# Analyzing page nr  782
# Analyzing page nr  783
# Analyzing page nr  784
# Analyzing page nr  785
# Analyzing page nr  786
# Analyzing page nr  787
# Analyzing page nr  788
# Analyzing page nr  789
# Analyzing page nr  790
# Analyzing page nr  791
# Analyzing page nr  792
# Analyzing page nr  793
# Analyzing page nr  794
# Analyzing page nr  795
# Analyzing page nr  796
# Analyzing page nr  797
# Analyzing page nr  798
# Analyzing page nr  799
# Analyzing page nr  800
# Analyzing page nr  801
# Analyzing page nr  802
# Analyzing page nr  803
# Analyzing page nr  804
# Analyzing page nr  805
# Analyzing page nr  806
# Analyzing page nr  807
# Analyzing page nr  808
# Analyzing page nr  809
# Analyzing page nr  810
# Analyzing page nr  811
# Analyzing page nr  812
# Analyzing page nr  813
# Analyzing page nr  814
# Analyzing page nr  815
# Analyzing page nr  816
# Analyzing page nr  817
# Analyzing page nr  818
# Analyzing page nr  819
# Analyzing page nr  820
# Analyzing page nr  821
# Analyzing page nr  822
# Analyzing page nr  823
# Analyzing page nr  824
# Analyzing page nr  825
# Analyzing page nr  826
# Analyzing page nr  827
# Analyzing page nr  828
# Analyzing page nr  829
# Analyzing page nr  830
# Analyzing page nr  831
# Analyzing page nr  832
# Analyzing page nr  833
# Analyzing page nr  834
# Analyzing page nr  835
# Analyzing page nr  836
# Analyzing page nr  837
# Analyzing page nr  838
# Analyzing page nr  839
# Analyzing page nr  840
# Analyzing page nr  841
# Analyzing page nr  842
# Analyzing page nr  843
# Analyzing page nr  844
# Analyzing page nr  845
# Analyzing page nr  846
# Analyzing page nr  847
# Analyzing page nr  848
# Analyzing page nr  849
# Analyzing page nr  850
# Analyzing page nr  851
# Analyzing page nr  852
# Analyzing page nr  853
# Analyzing page nr  854
# Analyzing page nr  855
# Analyzing page nr  856
# Analyzing page nr  857
# Analyzing page nr  858
# Analyzing page nr  859
# Analyzing page nr  860
# Analyzing page nr  861
# Analyzing page nr  862
# Analyzing page nr  863
# Analyzing page nr  864
# Analyzing page nr  865
# Analyzing page nr  866
# Analyzing page nr  867
# Analyzing page nr  868
# Analyzing page nr  869
# Analyzing page nr  870
# Analyzing page nr  871
# Analyzing page nr  872
# Analyzing page nr  873
# Analyzing page nr  874
# Analyzing page nr  875
# Analyzing page nr  876
# Analyzing page nr  877
# Analyzing page nr  878
# Analyzing page nr  879
# Analyzing page nr  880
# Analyzing page nr  881
# Analyzing page nr  882
# Analyzing page nr  883
# Analyzing page nr  884
# Analyzing page nr  885
# Analyzing page nr  886
# Analyzing page nr  887
# Analyzing page nr  888
# Analyzing page nr  889
# Analyzing page nr  890
# Analyzing page nr  891
# Analyzing page nr  892
# Analyzing page nr  893
# Analyzing page nr  894
# Analyzing page nr  895
# Analyzing page nr  896
# Analyzing page nr  897
# Analyzing page nr  898
# Analyzing page nr  899
# Analyzing page nr  900
# Analyzing page nr  901
# Analyzing page nr  902
# Analyzing page nr  903
# Analyzing page nr  904
# Analyzing page nr  905
# Analyzing page nr  906
# Analyzing page nr  907
# Analyzing page nr  908
# Analyzing page nr  909
# Analyzing page nr  910
# Analyzing page nr  911
# Analyzing page nr  912
# Analyzing page nr  913
# Analyzing page nr  914
# Analyzing page nr  915
# Analyzing page nr  916
# Analyzing page nr  917
# Analyzing page nr  918
# Analyzing page nr  919
# Analyzing page nr  920
# Analyzing page nr  921
# Analyzing page nr  922
# Analyzing page nr  923
# Analyzing page nr  924
# Analyzing page nr  925
# Analyzing page nr  926
# Analyzing page nr  927
# Analyzing page nr  928
# Analyzing page nr  929
# Analyzing page nr  930
# Analyzing page nr  931
# Analyzing page nr  932
# Analyzing page nr  933
# Analyzing page nr  934
# Analyzing page nr  935
# Analyzing page nr  936
# Analyzing page nr  937
# Analyzing page nr  938
# Analyzing page nr  939
# Analyzing page nr  940
# Analyzing page nr  941
# Analyzing page nr  942
# Analyzing page nr  943
# Analyzing page nr  944
# Analyzing page nr  945
# Analyzing page nr  946
# Analyzing page nr  947
# Analyzing page nr  948
# Analyzing page nr  949
# Analyzing page nr  950
# Analyzing page nr  951
# Analyzing page nr  952
# Analyzing page nr  953
# Analyzing page nr  954
# Analyzing page nr  955
# Analyzing page nr  956
# Analyzing page nr  957
# Analyzing page nr  958
# Analyzing page nr  959
# Analyzing page nr  960
# Analyzing page nr  961
# Analyzing page nr  962
# Analyzing page nr  963
# Analyzing page nr  964
# Analyzing page nr  965
# Analyzing page nr  966
# Analyzing page nr  967
# Analyzing page nr  968
# Analyzing page nr  969
# Analyzing page nr  970
# Analyzing page nr  971
# Analyzing page nr  972
# Analyzing page nr  973
# Analyzing page nr  974
# Analyzing page nr  975
# Analyzing page nr  976
# Analyzing page nr  977
# Analyzing page nr  978
# Analyzing page nr  979
# Analyzing page nr  980
# Analyzing page nr  981
# Analyzing page nr  982
# Analyzing page nr  983
# Analyzing page nr  984
# Analyzing page nr  985
# Analyzing page nr  986
# Analyzing page nr  987
# Analyzing page nr  988
# Analyzing page nr  989
# Analyzing page nr  990
# Analyzing page nr  991
# Analyzing page nr  992
# Analyzing page nr  993
# Analyzing page nr  994
# Analyzing page nr  995
# Analyzing page nr  996
# Analyzing page nr  997
# Analyzing page nr  998
# Analyzing page nr  999
# Analyzing page nr  1000
# Analyzing page nr  1001
# Analyzing page nr  1002
# Analyzing page nr  1003
# Analyzing page nr  1004
# Analyzing page nr  1005
# Analyzing page nr  1006
# Analyzing page nr  1007
# Analyzing page nr  1008
# Analyzing page nr  1009
# Analyzing page nr  1010
# Analyzing page nr  1011
# Analyzing page nr  1012
# Analyzing page nr  1013
# Analyzing page nr  1014
# Analyzing page nr  1015
# Analyzing page nr  1016
# Analyzing page nr  1017
# Analyzing page nr  1018
# Analyzing page nr  1019
# Analyzing page nr  1020
# Analyzing page nr  1021
# Analyzing page nr  1022
# Analyzing page nr  1023
# Analyzing page nr  1024
# Analyzing page nr  1025
# Analyzing page nr  1026
# Analyzing page nr  1027
# Analyzing page nr  1028
# Analyzing page nr  1029
# Analyzing page nr  1030
# Analyzing page nr  1031
# Analyzing page nr  1032
# Analyzing page nr  1033
# Analyzing page nr  1034
# Analyzing page nr  1035
# Analyzing page nr  1036
# Analyzing page nr  1037
# Analyzing page nr  1038
# Analyzing page nr  1039
# Analyzing page nr  1040
# Analyzing page nr  1041
# Analyzing page nr  1042
# Analyzing page nr  1043
# Analyzing page nr  1044
# Analyzing page nr  1045
# Analyzing page nr  1046
# Analyzing page nr  1047
# Analyzing page nr  1048
# Analyzing page nr  1049
# Analyzing page nr  1050
# Analyzing page nr  1051
# Analyzing page nr  1052
# Analyzing page nr  1053
# Analyzing page nr  1054
# Analyzing page nr  1055
# Analyzing page nr  1056
# Analyzing page nr  1057
# Analyzing page nr  1058
# Analyzing page nr  1059
# Analyzing page nr  1060
# Analyzing page nr  1061
# Analyzing page nr  1062
# Analyzing page nr  1063
# Analyzing page nr  1064
# Analyzing page nr  1065
# Analyzing page nr  1066
# Analyzing page nr  1067
# Analyzing page nr  1068
# Analyzing page nr  1069
# Analyzing page nr  1070
# Analyzing page nr  1071
# Analyzing page nr  1072
# Analyzing page nr  1073
# Analyzing page nr  1074
# Analyzing page nr  1075
# Analyzing page nr  1076
# Analyzing page nr  1077
# Analyzing page nr  1078
# Analyzing page nr  1079
# Analyzing page nr  1080
# Analyzing page nr  1081
# Analyzing page nr  1082
# Analyzing page nr  1083
# Analyzing page nr  1084
# Analyzing page nr  1085
# Analyzing page nr  1086
# Analyzing page nr  1087
# Analyzing page nr  1088
# Analyzing page nr  1089
# Analyzing page nr  1090
# Analyzing page nr  1091
# Analyzing page nr  1092
# Analyzing page nr  1093
# Analyzing page nr  1094
# Analyzing page nr  1095
# Analyzing page nr  1096
# Analyzing page nr  1097
# Analyzing page nr  1098
# Analyzing page nr  1099
# Analyzing page nr  1100
# Analyzing page nr  1101
# Analyzing page nr  1102
# Analyzing page nr  1103
# Analyzing page nr  1104
# Analyzing page nr  1105
# Analyzing page nr  1106
# Analyzing page nr  1107
# Analyzing page nr  1108
# Analyzing page nr  1109
# Analyzing page nr  1110
# Analyzing page nr  1111
# Analyzing page nr  1112
# Analyzing page nr  1113
# Analyzing page nr  1114
# Analyzing page nr  1115
# Analyzing page nr  1116
# Analyzing page nr  1117
# Analyzing page nr  1118
# Analyzing page nr  1119
# Analyzing page nr  1120
# Analyzing page nr  1121
# Analyzing page nr  1122
# Analyzing page nr  1123
# Analyzing page nr  1124
# Analyzing page nr  1125
# Analyzing page nr  1126
# Analyzing page nr  1127
# Analyzing page nr  1128
# Analyzing page nr  1129
# Analyzing page nr  1130
# Analyzing page nr  1131
# Analyzing page nr  1132
# Analyzing page nr  1133
# Analyzing page nr  1134
# Analyzing page nr  1135
# Analyzing page nr  1136
# Analyzing page nr  1137
# Analyzing page nr  1138
# Analyzing page nr  1139
# Analyzing page nr  1140
# Analyzing page nr  1141
# Analyzing page nr  1142
# Analyzing page nr  1143
# Analyzing page nr  1144
# Analyzing page nr  1145
# Analyzing page nr  1146
# Analyzing page nr  1147
# Analyzing page nr  1148
# Analyzing page nr  1149
# Analyzing page nr  1150
# Analyzing page nr  1151
# Analyzing page nr  1152
# Analyzing page nr  1153
# Analyzing page nr  1154
# Analyzing page nr  1155
# Analyzing page nr  1156
# Analyzing page nr  1157
# Analyzing page nr  1158
# Analyzing page nr  1159
# Analyzing page nr  1160
# Analyzing page nr  1161
# Analyzing page nr  1162
# Analyzing page nr  1163
# Analyzing page nr  1164
# Analyzing page nr  1165
# Analyzing page nr  1166
# Analyzing page nr  1167
# Analyzing page nr  1168
# Analyzing page nr  1169
# Analyzing page nr  1170
# Analyzing page nr  1171
# Analyzing page nr  1172
# Analyzing page nr  1173
# Analyzing page nr  1174
# Analyzing page nr  1175
# Analyzing page nr  1176
# Analyzing page nr  1177
# Analyzing page nr  1178
# Analyzing page nr  1179
# Analyzing page nr  1180
# Analyzing page nr  1181
# Analyzing page nr  1182
# Analyzing page nr  1183
# Analyzing page nr  1184
# Analyzing page nr  1185
# Analyzing page nr  1186
# Analyzing page nr  1187
# Analyzing page nr  1188
# Analyzing page nr  1189
# Analyzing page nr  1190
# Analyzing page nr  1191
# Analyzing page nr  1192
# Analyzing page nr  1193
# Analyzing page nr  1194
# Analyzing page nr  1195
# Analyzing page nr  1196
# Analyzing page nr  1197
# Analyzing page nr  1198
# Analyzing page nr  1199
# Analyzing page nr  1200
# Analyzing page nr  1201
# Analyzing page nr  1202
# Analyzing page nr  1203
# Analyzing page nr  1204
# Analyzing page nr  1205
# Analyzing page nr  1206
# Analyzing page nr  1207
# Analyzing page nr  1208
# Analyzing page nr  1209
# Analyzing page nr  1210
# Analyzing page nr  1211
# Analyzing page nr  1212
# Analyzing page nr  1213
# Analyzing page nr  1214
# Analyzing page nr  1215
# Analyzing page nr  1216
# Analyzing page nr  1217
# Analyzing page nr  1218
# Analyzing page nr  1219
# Analyzing page nr  1220
# Analyzing page nr  1221
# Analyzing page nr  1222
# Analyzing page nr  1223
# Analyzing page nr  1224
# Analyzing page nr  1225
# Analyzing page nr  1226
# Analyzing page nr  1227
# Analyzing page nr  1228
# Analyzing page nr  1229
# Analyzing page nr  1230
# Analyzing page nr  1231
# Analyzing page nr  1232
# Analyzing page nr  1233
# Analyzing page nr  1234
# Analyzing page nr  1235
# Analyzing page nr  1236
# Analyzing page nr  1237
# Analyzing page nr  1238
# Analyzing page nr  1239
# Analyzing page nr  1240
# Analyzing page nr  1241
# Analyzing page nr  1242
# Analyzing page nr  1243
# Analyzing page nr  1244
# Analyzing page nr  1245
# Analyzing page nr  1246
# Analyzing page nr  1247
# Analyzing page nr  1248
# Analyzing page nr  1249
# Analyzing page nr  1250
# Analyzing page nr  1251
# Analyzing page nr  1252
# Analyzing page nr  1253
# Analyzing page nr  1254
# Analyzing page nr  1255
# Analyzing page nr  1256
# Analyzing page nr  1257
# Analyzing page nr  1258
# Analyzing page nr  1259
# Analyzing page nr  1260
# Analyzing page nr  1261
# Analyzing page nr  1262
# Analyzing page nr  1263
# Analyzing page nr  1264
# Analyzing page nr  1265
# Analyzing page nr  1266
# Analyzing page nr  1267
# Analyzing page nr  1268
# Analyzing page nr  1269
# Analyzing page nr  1270
# Analyzing page nr  1271
# Analyzing page nr  1272
# Analyzing page nr  1273
# Analyzing page nr  1274
# Analyzing page nr  1275
# Analyzing page nr  1276
# Analyzing page nr  1277
# Analyzing page nr  1278
# Analyzing page nr  1279
# Analyzing page nr  1280
# Analyzing page nr  1281
# Analyzing page nr  1282
# Analyzing page nr  1283
# Analyzing page nr  1284
# Analyzing page nr  1285
# Analyzing page nr  1286
# Analyzing page nr  1287
# Analyzing page nr  1288
# Analyzing page nr  1289
# Analyzing page nr  1290
# Analyzing page nr  1291
# Analyzing page nr  1292
# Analyzing page nr  1293
# Analyzing page nr  1294
# Analyzing page nr  1295
# Analyzing page nr  1296
# Analyzing page nr  1297
# Analyzing page nr  1298
# Analyzing page nr  1299
# Analyzing page nr  1300
# Analyzing page nr  1301
# Analyzing page nr  1302
# Analyzing page nr  1303
# Analyzing page nr  1304
# Analyzing page nr  1305
# Analyzing page nr  1306
# Analyzing page nr  1307
# Analyzing page nr  1308
# Analyzing page nr  1309
# Analyzing page nr  1310
# Analyzing page nr  1311
# Analyzing page nr  1312
# Analyzing page nr  1313
# Analyzing page nr  1314
# Analyzing page nr  1315
# Analyzing page nr  1316
# Analyzing page nr  1317
# Analyzing page nr  1318
# Analyzing page nr  1319
# Analyzing page nr  1320
# Analyzing page nr  1321
# Analyzing page nr  1322
# Analyzing page nr  1323
# Analyzing page nr  1324
# Analyzing page nr  1325
# Analyzing page nr  1326
# Analyzing page nr  1327
# Analyzing page nr  1328
# Analyzing page nr  1329
# Analyzing page nr  1330
# Analyzing page nr  1331
# Analyzing page nr  1332
# Analyzing page nr  1333
# Analyzing page nr  1334
# Analyzing page nr  1335
# Analyzing page nr  1336
# Analyzing page nr  1337
# Analyzing page nr  1338
# Analyzing page nr  1339
# Analyzing page nr  1340
# Analyzing page nr  1341
# Analyzing page nr  1342
# Analyzing page nr  1343
# Analyzing page nr  1344
# Analyzing page nr  1345
# Analyzing page nr  1346
# Analyzing page nr  1347
# Analyzing page nr  1348
# Analyzing page nr  1349
# Analyzing page nr  1350
# Analyzing page nr  1351
# Analyzing page nr  1352
# Analyzing page nr  1353
# Analyzing page nr  1354
# Analyzing page nr  1355
# Analyzing page nr  1356
# Analyzing page nr  1357
# Analyzing page nr  1358
# Analyzing page nr  1359
# Analyzing page nr  1360
# Analyzing page nr  1361
# Analyzing page nr  1362
# Analyzing page nr  1363
# Analyzing page nr  1364
# Analyzing page nr  1365
# Analyzing page nr  1366
# Analyzing page nr  1367
# Analyzing page nr  1368
# Analyzing page nr  1369
# Analyzing page nr  1370
# Analyzing page nr  1371
# Analyzing page nr  1372
# Analyzing page nr  1373
# Analyzing page nr  1374
# Analyzing page nr  1375
# Analyzing page nr  1376
# Analyzing page nr  1377
# Analyzing page nr  1378
# Analyzing page nr  1379
# Analyzing page nr  1380
# Analyzing page nr  1381
# Analyzing page nr  1382
# Analyzing page nr  1383
# Analyzing page nr  1384
# Analyzing page nr  1385
# Analyzing page nr  1386
# Analyzing page nr  1387
# Analyzing page nr  1388
# Analyzing page nr  1389
# Analyzing page nr  1390
# Analyzing page nr  1391
# Analyzing page nr  1392
# Analyzing page nr  1393
# Analyzing page nr  1394
# Analyzing page nr  1395
# Analyzing page nr  1396
# Analyzing page nr  1397
# Analyzing page nr  1398
# Analyzing page nr  1399
# Analyzing page nr  1400
# Analyzing page nr  1401
# Analyzing page nr  1402
# Analyzing page nr  1403
# Analyzing page nr  1404
# Analyzing page nr  1405
# Analyzing page nr  1406
# Analyzing page nr  1407
# Analyzing page nr  1408
# Analyzing page nr  1409
# Analyzing page nr  1410
# Analyzing page nr  1411
# Analyzing page nr  1412
# Analyzing page nr  1413
# Analyzing page nr  1414
# Analyzing page nr  1415
# Analyzing page nr  1416
# Analyzing page nr  1417
# Analyzing page nr  1418
# Analyzing page nr  1419
# Analyzing page nr  1420
# Analyzing page nr  1421
# Analyzing page nr  1422
# Analyzing page nr  1423
# Analyzing page nr  1424
# Analyzing page nr  1425
# Analyzing page nr  1426
# Analyzing page nr  1427
# Analyzing page nr  1428
# Analyzing page nr  1429
# Analyzing page nr  1430
# Analyzing page nr  1431
# Analyzing page nr  1432
# Analyzing page nr  1433
# Analyzing page nr  1434
# Analyzing page nr  1435
# Analyzing page nr  1436
# Analyzing page nr  1437
# Analyzing page nr  1438
# Analyzing page nr  1439
# Analyzing page nr  1440
# Analyzing page nr  1441
# Analyzing page nr  1442
# Analyzing page nr  1443
# Analyzing page nr  1444
# Analyzing page nr  1445
# Analyzing page nr  1446
# Analyzing page nr  1447
# Analyzing page nr  1448
# Analyzing page nr  1449
# Analyzing page nr  1450
# Analyzing page nr  1451
# Analyzing page nr  1452
# Analyzing page nr  1453
# Analyzing page nr  1454
# Analyzing page nr  1455
# Analyzing page nr  1456
# Analyzing page nr  1457
# Analyzing page nr  1458
# Analyzing page nr  1459
# Analyzing page nr  1460
# Analyzing page nr  1461
# Analyzing page nr  1462
# Analyzing page nr  1463
# Analyzing page nr  1464
# Analyzing page nr  1465
# Analyzing page nr  1466
# Analyzing page nr  1467
# Analyzing page nr  1468
# Analyzing page nr  1469
# Analyzing page nr  1470
# Analyzing page nr  1471
# Analyzing page nr  1472
# Analyzing page nr  1473
# Analyzing page nr  1474
# Analyzing page nr  1475
# Analyzing page nr  1476
# Analyzing page nr  1477
# Analyzing page nr  1478
# Analyzing page nr  1479
# Analyzing page nr  1480
# Analyzing page nr  1481
# Analyzing page nr  1482
# Analyzing page nr  1483
# Analyzing page nr  1484
# Analyzing page nr  1485
# Analyzing page nr  1486
# Analyzing page nr  1487
# Analyzing page nr  1488
# Analyzing page nr  1489
# Analyzing page nr  1490
# Analyzing page nr  1491
# Analyzing page nr  1492
# Analyzing page nr  1493
# Analyzing page nr  1494
# Analyzing page nr  1495
# Analyzing page nr  1496
# Analyzing page nr  1497
# Analyzing page nr  1498
# Analyzing page nr  1499
# Analyzing page nr  1500
# Analyzing page nr  1501
# Analyzing page nr  1502
# Analyzing page nr  1503
# Analyzing page nr  1504
# Analyzing page nr  1505
# Analyzing page nr  1506
# Analyzing page nr  1507
# Analyzing page nr  1508
# Analyzing page nr  1509
# Analyzing page nr  1510
# Analyzing page nr  1511
# Analyzing page nr  1512
# Analyzing page nr  1513
# Analyzing page nr  1514
# Analyzing page nr  1515
# Analyzing page nr  1516
# Analyzing page nr  1517
# Analyzing page nr  1518
# Analyzing page nr  1519
# Analyzing page nr  1520
# Analyzing page nr  1521
# Analyzing page nr  1522
# Analyzing page nr  1523
# Analyzing page nr  1524
# Analyzing page nr  1525
# Analyzing page nr  1526
# Analyzing page nr  1527
# Analyzing page nr  1528
# Analyzing page nr  1529
# Analyzing page nr  1530
# Analyzing page nr  1531
# Analyzing page nr  1532
# Analyzing page nr  1533
# Analyzing page nr  1534
# Analyzing page nr  1535
# Analyzing page nr  1536
# Analyzing page nr  1537
# Analyzing page nr  1538
# Analyzing page nr  1539
# Analyzing page nr  1540
# Analyzing page nr  1541
# Analyzing page nr  1542
# Analyzing page nr  1543
# Analyzing page nr  1544
# Analyzing page nr  1545
# Analyzing page nr  1546
# Analyzing page nr  1547
# Analyzing page nr  1548
# Analyzing page nr  1549
# Analyzing page nr  1550
# Analyzing page nr  1551
# Analyzing page nr  1552
# Analyzing page nr  1553
# Analyzing page nr  1554
# Analyzing page nr  1555
# Analyzing page nr  1556
# Analyzing page nr  1557
# Analyzing page nr  1558
# Analyzing page nr  1559
# Analyzing page nr  1560
# Analyzing page nr  1561
# Analyzing page nr  1562
# Analyzing page nr  1563
# Analyzing page nr  1564
# Analyzing page nr  1565
# Analyzing page nr  1566
# Analyzing page nr  1567
# Analyzing page nr  1568
# Analyzing page nr  1569
# Analyzing page nr  1570
# Analyzing page nr  1571
# Analyzing page nr  1572
# Analyzing page nr  1573
# Analyzing page nr  1574
# Analyzing page nr  1575
# Analyzing page nr  1576
# Analyzing page nr  1577
# Analyzing page nr  1578
# Analyzing page nr  1579
# Analyzing page nr  1580
# Analyzing page nr  1581
# Analyzing page nr  1582
# Analyzing page nr  1583
# Analyzing page nr  1584
# Analyzing page nr  1585
# Analyzing page nr  1586
# Analyzing page nr  1587
# Analyzing page nr  1588
# Analyzing page nr  1589
# Analyzing page nr  1590
# Analyzing page nr  1591
# Analyzing page nr  1592
# Analyzing page nr  1593
# Analyzing page nr  1594
# Analyzing page nr  1595
# Analyzing page nr  1596
# Analyzing page nr  1597
# Analyzing page nr  1598
# Analyzing page nr  1599
# Analyzing page nr  1600
# Analyzing page nr  1601
# Analyzing page nr  1602
# Analyzing page nr  1603
# Analyzing page nr  1604
# Analyzing page nr  1605
# Analyzing page nr  1606
# Analyzing page nr  1607
# Analyzing page nr  1608
# Analyzing page nr  1609
# Analyzing page nr  1610
# Analyzing page nr  1611
# Analyzing page nr  1612
# Analyzing page nr  1613
# Analyzing page nr  1614
# Analyzing page nr  1615
# Analyzing page nr  1616
# Analyzing page nr  1617
# Analyzing page nr  1618
# Analyzing page nr  1619
# Analyzing page nr  1620
# Analyzing page nr  1621
# Analyzing page nr  1622
# Analyzing page nr  1623
# Analyzing page nr  1624
# Analyzing page nr  1625
# Analyzing page nr  1626
# Analyzing page nr  1627
# Analyzing page nr  1628
# Analyzing page nr  1629
# Analyzing page nr  1630
# Analyzing page nr  1631
# Analyzing page nr  1632
# Analyzing page nr  1633
# Analyzing page nr  1634
# Analyzing page nr  1635
# Analyzing page nr  1636
# Analyzing page nr  1637
# Analyzing page nr  1638
# Analyzing page nr  1639
# Analyzing page nr  1640
# Analyzing page nr  1641
# Analyzing page nr  1642
# Analyzing page nr  1643
# Analyzing page nr  1644
# Analyzing page nr  1645
# Analyzing page nr  1646
# Analyzing page nr  1647
# Analyzing page nr  1648
# Analyzing page nr  1649
# Analyzing page nr  1650
# Analyzing page nr  1651
# Analyzing page nr  1652
# Analyzing page nr  1653
# Analyzing page nr  1654
# Analyzing page nr  1655
# Analyzing page nr  1656
# Analyzing page nr  1657
# Analyzing page nr  1658
# Analyzing page nr  1659
# Analyzing page nr  1660
# Analyzing page nr  1661
# Analyzing page nr  1662
# Analyzing page nr  1663
# Analyzing page nr  1664
# Analyzing page nr  1665
# Analyzing page nr  1666
# Analyzing page nr  1667
# Analyzing page nr  1668
# Analyzing page nr  1669
# Analyzing page nr  1670
# Analyzing page nr  1671
# Analyzing page nr  1672
# Analyzing page nr  1673
# Analyzing page nr  1674
# Analyzing page nr  1675
# Analyzing page nr  1676
# Analyzing page nr  1677
# Analyzing page nr  1678
# Analyzing page nr  1679
# Analyzing page nr  1680
# Analyzing page nr  1681
# Analyzing page nr  1682
# Analyzing page nr  1683
# Analyzing page nr  1684
# Analyzing page nr  1685
# Analyzing page nr  1686
# Analyzing page nr  1687
# Analyzing page nr  1688
# Analyzing page nr  1689
# Analyzing page nr  1690
# Analyzing page nr  1691
# Analyzing page nr  1692
# Analyzing page nr  1693
# Analyzing page nr  1694
# Analyzing page nr  1695
# Analyzing page nr  1696
# Analyzing page nr  1697
# Analyzing page nr  1698
# Analyzing page nr  1699
# Analyzing page nr  1700
# Analyzing page nr  1701
# Analyzing page nr  1702
# Analyzing page nr  1703
# Analyzing page nr  1704
# Analyzing page nr  1705
# Analyzing page nr  1706
# Analyzing page nr  1707
# Analyzing page nr  1708
# Analyzing page nr  1709
# Analyzing page nr  1710
# Analyzing page nr  1711
# Analyzing page nr  1712
# Analyzing page nr  1713
# Analyzing page nr  1714
# Analyzing page nr  1715
# Analyzing page nr  1716
# Analyzing page nr  1717
# Analyzing page nr  1718
# Analyzing page nr  1719
# Analyzing page nr  1720
# Analyzing page nr  1721
# Analyzing page nr  1722
# Analyzing page nr  1723
# Analyzing page nr  1724
# Analyzing page nr  1725
# Analyzing page nr  1726
# Analyzing page nr  1727
# Analyzing page nr  1728
# Analyzing page nr  1729
# Analyzing page nr  1730
# Analyzing page nr  1731
# Analyzing page nr  1732
# Analyzing page nr  1733
# Analyzing page nr  1734
# Analyzing page nr  1735
# Analyzing page nr  1736
# Analyzing page nr  1737
# Analyzing page nr  1738
# Analyzing page nr  1739
# Analyzing page nr  1740
# Analyzing page nr  1741
# Analyzing page nr  1742
# Analyzing page nr  1743
# Analyzing page nr  1744
# Analyzing page nr  1745
# Analyzing page nr  1746
# Analyzing page nr  1747
# Analyzing page nr  1748
# Analyzing page nr  1749
# Analyzing page nr  1750
# Analyzing page nr  1751
# Analyzing page nr  1752
# Analyzing page nr  1753
# Analyzing page nr  1754
# Analyzing page nr  1755
# Analyzing page nr  1756
# Analyzing page nr  1757
# Analyzing page nr  1758
# Analyzing page nr  1759
# Analyzing page nr  1760
# Analyzing page nr  1761
# Analyzing page nr  1762
# Analyzing page nr  1763
# Analyzing page nr  1764
# Analyzing page nr  1765
# Analyzing page nr  1766
# Analyzing page nr  1767
# Analyzing page nr  1768
# Analyzing page nr  1769
# Analyzing page nr  1770
# Analyzing page nr  1771
# Analyzing page nr  1772
# Analyzing page nr  1773
# Analyzing page nr  1774
# Analyzing page nr  1775
# Analyzing page nr  1776
# Analyzing page nr  1777
# Analyzing page nr  1778
# Analyzing page nr  1779
# Analyzing page nr  1780
# Analyzing page nr  1781
# Analyzing page nr  1782
# Analyzing page nr  1783
# Analyzing page nr  1784
# Analyzing page nr  1785
# Analyzing page nr  1786
# Analyzing page nr  1787
# Analyzing page nr  1788
# Analyzing page nr  1789
# Analyzing page nr  1790
# Analyzing page nr  1791
# Analyzing page nr  1792
# Analyzing page nr  1793
# Analyzing page nr  1794
# Analyzing page nr  1795
# Analyzing page nr  1796
# Analyzing page nr  1797
# Analyzing page nr  1798
# Analyzing page nr  1799
# Analyzing page nr  1800
# Analyzing page nr  1801
# Analyzing page nr  1802
# Analyzing page nr  1803
# Analyzing page nr  1804
# Analyzing page nr  1805
# Analyzing page nr  1806
# Analyzing page nr  1807
# Analyzing page nr  1808
# Analyzing page nr  1809
# Analyzing page nr  1810
# Analyzing page nr  1811
# Analyzing page nr  1812
# Analyzing page nr  1813
# Analyzing page nr  1814
# Analyzing page nr  1815
# Analyzing page nr  1816
# Analyzing page nr  1817
# Analyzing page nr  1818
# Analyzing page nr  1819
# Analyzing page nr  1820
# Analyzing page nr  1821
# Analyzing page nr  1822
# Analyzing page nr  1823
# Analyzing page nr  1824
# Analyzing page nr  1825
# Analyzing page nr  1826
# Analyzing page nr  1827
# Analyzing page nr  1828
# Analyzing page nr  1829
# We gathered: 17580 statements

# %% [markdown]
# ## Some analysis
# Though unrelated to the purpose of this work, it could be interesting to check a few simple statistics on the data.

# %%
df = pd.DataFrame(statements)
df['date'] = pd.to_datetime(df['date'])

# %%
len(df)
# Out:
# 17580

# %%
df.head()
# Out:
#                                             sentence          author  \
# 0  Kamala Harris said, "I don't like Joe Biden an...  Facebook posts
# 1  Condoleezza Rice said, "If you are taught bitt...  Facebook posts
# 2  A coloring book that describes Joe Biden as "A...     Viral image
# 3  "In West Virginia alone, overdoses have increa...    Carol Miller
# 4  The United States is "the only major industria...    Bill Clinton
#
#                        target       ruling       date
# 0  [Joe Biden, Kamala Harris]        false 2020-08-19
# 1                          []    half-true 2020-08-19
# 2                 [Joe Biden]        false 2020-08-19
# 3                          []  mostly-true 2020-08-19
# 4                          []  mostly-true 2020-08-18

# %%
df["author"].value_counts()
# Out:
# Donald Trump               828
# Facebook posts             783
# Barack Obama               589
# Bloggers                   585
# Viral image                464
#                           ...
# Josh Pade                    1
# Activist Mommy               1
# Fellowship of the Minds      1
# James Roosevelt              1
# Senfronia Thompson           1
# Name: author, Length: 4121, dtype: int64

# %%
df["ruling"].value_counts()
# Out:
# false          3826
# half-true      3199
# mostly-true    3035
# barely-true    2913
# true           2327
# pants-fire     2038
# full-flop       152
# half-flip        66
# no-flip          24
# Name: ruling, dtype: int64

# %%
df["target"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                              13722
# [Barack Obama]                    494
# [Donald Trump]                    252
# [Scott Walker]                    155
# [Hillary Clinton]                 149
#                                 ...
# [Brian Robinson]                    1
# [Scott Fitzgerald]                  1
# [Charlie Crist, Marco Rubio]        1
# [Wayne LaPierre]                    1
# [Morgan Griffith]                   1
# Name: target, Length: 849, dtype: int64

# %%
df['date']
# Out:
# 0       2020-08-19
# 1       2020-08-19
# 2       2020-08-19
# 3       2020-08-19
# 4       2020-08-18
#            ...
# 11015   2013-03-11
# 11016   2013-03-11
# 11017   2013-03-11
# 11018   2013-03-11
# 11019   2013-03-11
# Name: date, Length: 11020, dtype: datetime64[ns]

# %%
df.to_csv("checkworthy_claims.csv", index=False)

# %% [markdown]
# ## Retrieve articles url
# Previous step was necessary to create a dataset of checkworthy claims. Now, we want to build a dataset of fact-checking articles.

# %% [markdown]
# It would be possible to gather most information directly from the file obtained through the Politifact API, but since some info (like claimDate or imageURL) are not accessible here, I prefer to build a dataset of URL and then scrape them directly from the website.

# %% [markdown]
# Politifact urls have this form:
#  - https://www.politifact.com/factchecks/2020/aug/18/viral-image/photo-doesnt-show-kamala-harris-listed-caucasian-h/
#  - "https://www.politifact.com/factchecks/" + year + "/" + month (3 letters) + "/" + day + "/" + speaker_slug + "/" + article_slug + "/"

# %% [markdown]
# We will put the urls in a dataset which will contain:
#  - claim
#  - claimant
#  - url
#  - reviewDate
#  - Rating
#  - languageCode (en)
#  - publisherName (Politifact)
#  - publisherSite (politifact.com)
#  - UniformRating (to get from Rating)
#  - claimLink (null)

# %% [markdown]
# We will then scrape the following info:
#  - claimDate
#  - reviewTitle
#  - articleBody
#  - imageUrl

# %% [markdown]
# For reference on what these fields mean, please take a look at [this notebook ](https://colab.research.google.com/drive/15dYezybEwZXGbwvWfgQRfBWrImGxqisF?usp=sharing)

# %%
def build_url(article_slug, speaker_slug, date):
    url = "https://www.politifact.com/factchecks/"
    url += str(date.year)
    url += "/"
    url += date.strftime("%b").lower()
    url += "/"
    url += str(date.day)
    url += "/"
    url += speaker_slug
    url += "/"
    url += article_slug
    url += "/"
    return url

# %%
statements = []
for num_page in range(1,1830):

    # Load a saved html
    print("Analyzing page nr ", num_page)
    with open("html_pages/{}.html".format(num_page), "r", encoding="utf-8") as f:
            html = f.read()

    #Remove the header
    json_rows = html.split('{"id":')[1:]

    for row in json_rows:
        statement = {}
        
        #Retrieve the slugs needed for the url
        article_slug = row.split('"slug":"')[1].split('","speaker"')[0]
        speaker_slug = row.split('"speaker":{"slug":"')[1].split('","full_name"')[0]
        date = row.split('"publication_date":"')[1].split('T')[0]
        date = datetime.datetime.strptime(date, '%Y-%m-%d')
        
        #Retrieve the other necessary info
        claim = row.split('"statement":"')[1].split('","ruling_slug')[0]
        claimant = row.split('"speaker":')[1].split(',"targets"')[0]
        rating = row.split('"ruling_slug":"')[1].split('","publication_date":')[0]
        
        #Create the dataset entry
        statement['claim'] = clean_sentence(claim)
        statement['claimant'] = clean_author(claimant)
        statement['url'] = build_url(article_slug, speaker_slug, date)
        statement['reviewDate'] = date
        statement['Rating'] = rating
        statement['languageCode'] = 'en'
        statement['publisherName'] = 'Politifact'
        statement['publisherSite'] = 'politifact.com'
        statement['claimLink'] = 'NaN'
        
        statements.append(statement)
        
print("We gathered {0} statements".format(len(statements)))
# Out:
# Analyzing page nr  1
# Analyzing page nr  2
# Analyzing page nr  3
# Analyzing page nr  4
# Analyzing page nr  5
# Analyzing page nr  6
# Analyzing page nr  7
# Analyzing page nr  8
# Analyzing page nr  9
# Analyzing page nr  10
# Analyzing page nr  11
# Analyzing page nr  12
# Analyzing page nr  13
# Analyzing page nr  14
# Analyzing page nr  15
# Analyzing page nr  16
# Analyzing page nr  17
# Analyzing page nr  18
# Analyzing page nr  19
# Analyzing page nr  20
# Analyzing page nr  21
# Analyzing page nr  22
# Analyzing page nr  23
# Analyzing page nr  24
# Analyzing page nr  25
# Analyzing page nr  26
# Analyzing page nr  27
# Analyzing page nr  28
# Analyzing page nr  29
# Analyzing page nr  30
# Analyzing page nr  31
# Analyzing page nr  32
# Analyzing page nr  33
# Analyzing page nr  34
# Analyzing page nr  35
# Analyzing page nr  36
# Analyzing page nr  37
# Analyzing page nr  38
# Analyzing page nr  39
# Analyzing page nr  40
# Analyzing page nr  41
# Analyzing page nr  42
# Analyzing page nr  43
# Analyzing page nr  44
# Analyzing page nr  45
# Analyzing page nr  46
# Analyzing page nr  47
# Analyzing page nr  48
# Analyzing page nr  49
# Analyzing page nr  50
# Analyzing page nr  51
# Analyzing page nr  52
# Analyzing page nr  53
# Analyzing page nr  54
# Analyzing page nr  55
# Analyzing page nr  56
# Analyzing page nr  57
# Analyzing page nr  58
# Analyzing page nr  59
# Analyzing page nr  60
# Analyzing page nr  61
# Analyzing page nr  62
# Analyzing page nr  63
# Analyzing page nr  64
# Analyzing page nr  65
# Analyzing page nr  66
# Analyzing page nr  67
# Analyzing page nr  68
# Analyzing page nr  69
# Analyzing page nr  70
# Analyzing page nr  71
# Analyzing page nr  72
# Analyzing page nr  73
# Analyzing page nr  74
# Analyzing page nr  75
# Analyzing page nr  76
# Analyzing page nr  77
# Analyzing page nr  78
# Analyzing page nr  79
# Analyzing page nr  80
# Analyzing page nr  81
# Analyzing page nr  82
# Analyzing page nr  83
# Analyzing page nr  84
# Analyzing page nr  85
# Analyzing page nr  86
# Analyzing page nr  87
# Analyzing page nr  88
# Analyzing page nr  89
# Analyzing page nr  90
# Analyzing page nr  91
# Analyzing page nr  92
# Analyzing page nr  93
# Analyzing page nr  94
# Analyzing page nr  95
# Analyzing page nr  96
# Analyzing page nr  97
# Analyzing page nr  98
# Analyzing page nr  99
# Analyzing page nr  100
# Analyzing page nr  101
# Analyzing page nr  102
# Analyzing page nr  103
# Analyzing page nr  104
# Analyzing page nr  105
# Analyzing page nr  106
# Analyzing page nr  107
# Analyzing page nr  108
# Analyzing page nr  109
# Analyzing page nr  110
# Analyzing page nr  111
# Analyzing page nr  112
# Analyzing page nr  113
# Analyzing page nr  114
# Analyzing page nr  115
# Analyzing page nr  116
# Analyzing page nr  117
# Analyzing page nr  118
# Analyzing page nr  119
# Analyzing page nr  120
# Analyzing page nr  121
# Analyzing page nr  122
# Analyzing page nr  123
# Analyzing page nr  124
# Analyzing page nr  125
# Analyzing page nr  126
# Analyzing page nr  127
# Analyzing page nr  128
# Analyzing page nr  129
# Analyzing page nr  130
# Analyzing page nr  131
# Analyzing page nr  132
# Analyzing page nr  133
# Analyzing page nr  134
# Analyzing page nr  135
# Analyzing page nr  136
# Analyzing page nr  137
# Analyzing page nr  138
# Analyzing page nr  139
# Analyzing page nr  140
# Analyzing page nr  141
# Analyzing page nr  142
# Analyzing page nr  143
# Analyzing page nr  144
# Analyzing page nr  145
# Analyzing page nr  146
# Analyzing page nr  147
# Analyzing page nr  148
# Analyzing page nr  149
# Analyzing page nr  150
# Analyzing page nr  151
# Analyzing page nr  152
# Analyzing page nr  153
# Analyzing page nr  154
# Analyzing page nr  155
# Analyzing page nr  156
# Analyzing page nr  157
# Analyzing page nr  158
# Analyzing page nr  159
# Analyzing page nr  160
# Analyzing page nr  161
# Analyzing page nr  162
# Analyzing page nr  163
# Analyzing page nr  164
# Analyzing page nr  165
# Analyzing page nr  166
# Analyzing page nr  167
# Analyzing page nr  168
# Analyzing page nr  169
# Analyzing page nr  170
# Analyzing page nr  171
# Analyzing page nr  172
# Analyzing page nr  173
# Analyzing page nr  174
# Analyzing page nr  175
# Analyzing page nr  176
# Analyzing page nr  177
# Analyzing page nr  178
# Analyzing page nr  179
# Analyzing page nr  180
# Analyzing page nr  181
# Analyzing page nr  182
# Analyzing page nr  183
# Analyzing page nr  184
# Analyzing page nr  185
# Analyzing page nr  186
# Analyzing page nr  187
# Analyzing page nr  188
# Analyzing page nr  189
# Analyzing page nr  190
# Analyzing page nr  191
# Analyzing page nr  192
# Analyzing page nr  193
# Analyzing page nr  194
# Analyzing page nr  195
# Analyzing page nr  196
# Analyzing page nr  197
# Analyzing page nr  198
# Analyzing page nr  199
# Analyzing page nr  200
# Analyzing page nr  201
# Analyzing page nr  202
# Analyzing page nr  203
# Analyzing page nr  204
# Analyzing page nr  205
# Analyzing page nr  206
# Analyzing page nr  207
# Analyzing page nr  208
# Analyzing page nr  209
# Analyzing page nr  210
# Analyzing page nr  211
# Analyzing page nr  212
# Analyzing page nr  213
# Analyzing page nr  214
# Analyzing page nr  215
# Analyzing page nr  216
# Analyzing page nr  217
# Analyzing page nr  218
# Analyzing page nr  219
# Analyzing page nr  220
# Analyzing page nr  221
# Analyzing page nr  222
# Analyzing page nr  223
# Analyzing page nr  224
# Analyzing page nr  225
# Analyzing page nr  226
# Analyzing page nr  227
# Analyzing page nr  228
# Analyzing page nr  229
# Analyzing page nr  230
# Analyzing page nr  231
# Analyzing page nr  232
# Analyzing page nr  233
# Analyzing page nr  234
# Analyzing page nr  235
# Analyzing page nr  236
# Analyzing page nr  237
# Analyzing page nr  238
# Analyzing page nr  239
# Analyzing page nr  240
# Analyzing page nr  241
# Analyzing page nr  242
# Analyzing page nr  243
# Analyzing page nr  244
# Analyzing page nr  245
# Analyzing page nr  246
# Analyzing page nr  247
# Analyzing page nr  248
# Analyzing page nr  249
# Analyzing page nr  250
# Analyzing page nr  251
# Analyzing page nr  252
# Analyzing page nr  253
# Analyzing page nr  254
# Analyzing page nr  255
# Analyzing page nr  256
# Analyzing page nr  257
# Analyzing page nr  258
# Analyzing page nr  259
# Analyzing page nr  260
# Analyzing page nr  261
# Analyzing page nr  262
# Analyzing page nr  263
# Analyzing page nr  264
# Analyzing page nr  265
# Analyzing page nr  266
# Analyzing page nr  267
# Analyzing page nr  268
# Analyzing page nr  269
# Analyzing page nr  270
# Analyzing page nr  271
# Analyzing page nr  272
# Analyzing page nr  273
# Analyzing page nr  274
# Analyzing page nr  275
# Analyzing page nr  276
# Analyzing page nr  277
# Analyzing page nr  278
# Analyzing page nr  279
# Analyzing page nr  280
# Analyzing page nr  281
# Analyzing page nr  282
# Analyzing page nr  283
# Analyzing page nr  284
# Analyzing page nr  285
# Analyzing page nr  286
# Analyzing page nr  287
# Analyzing page nr  288
# Analyzing page nr  289
# Analyzing page nr  290
# Analyzing page nr  291
# Analyzing page nr  292
# Analyzing page nr  293
# Analyzing page nr  294
# Analyzing page nr  295
# Analyzing page nr  296
# Analyzing page nr  297
# Analyzing page nr  298
# Analyzing page nr  299
# Analyzing page nr  300
# Analyzing page nr  301
# Analyzing page nr  302
# Analyzing page nr  303
# Analyzing page nr  304
# Analyzing page nr  305
# Analyzing page nr  306
# Analyzing page nr  307
# Analyzing page nr  308
# Analyzing page nr  309
# Analyzing page nr  310
# Analyzing page nr  311
# Analyzing page nr  312
# Analyzing page nr  313
# Analyzing page nr  314
# Analyzing page nr  315
# Analyzing page nr  316
# Analyzing page nr  317
# Analyzing page nr  318
# Analyzing page nr  319
# Analyzing page nr  320
# Analyzing page nr  321
# Analyzing page nr  322
# Analyzing page nr  323
# Analyzing page nr  324
# Analyzing page nr  325
# Analyzing page nr  326
# Analyzing page nr  327
# Analyzing page nr  328
# Analyzing page nr  329
# Analyzing page nr  330
# Analyzing page nr  331
# Analyzing page nr  332
# Analyzing page nr  333
# Analyzing page nr  334
# Analyzing page nr  335
# Analyzing page nr  336
# Analyzing page nr  337
# Analyzing page nr  338
# Analyzing page nr  339
# Analyzing page nr  340
# Analyzing page nr  341
# Analyzing page nr  342
# Analyzing page nr  343
# Analyzing page nr  344
# Analyzing page nr  345
# Analyzing page nr  346
# Analyzing page nr  347
# Analyzing page nr  348
# Analyzing page nr  349
# Analyzing page nr  350
# Analyzing page nr  351
# Analyzing page nr  352
# Analyzing page nr  353
# Analyzing page nr  354
# Analyzing page nr  355
# Analyzing page nr  356
# Analyzing page nr  357
# Analyzing page nr  358
# Analyzing page nr  359
# Analyzing page nr  360
# Analyzing page nr  361
# Analyzing page nr  362
# Analyzing page nr  363
# Analyzing page nr  364
# Analyzing page nr  365
# Analyzing page nr  366
# Analyzing page nr  367
# Analyzing page nr  368
# Analyzing page nr  369
# Analyzing page nr  370
# Analyzing page nr  371
# Analyzing page nr  372
# Analyzing page nr  373
# Analyzing page nr  374
# Analyzing page nr  375
# Analyzing page nr  376
# Analyzing page nr  377
# Analyzing page nr  378
# Analyzing page nr  379
# Analyzing page nr  380
# Analyzing page nr  381
# Analyzing page nr  382
# Analyzing page nr  383
# Analyzing page nr  384
# Analyzing page nr  385
# Analyzing page nr  386
# Analyzing page nr  387
# Analyzing page nr  388
# Analyzing page nr  389
# Analyzing page nr  390
# Analyzing page nr  391
# Analyzing page nr  392
# Analyzing page nr  393
# Analyzing page nr  394
# Analyzing page nr  395
# Analyzing page nr  396
# Analyzing page nr  397
# Analyzing page nr  398
# Analyzing page nr  399
# Analyzing page nr  400
# Analyzing page nr  401
# Analyzing page nr  402
# Analyzing page nr  403
# Analyzing page nr  404
# Analyzing page nr  405
# Analyzing page nr  406
# Analyzing page nr  407
# Analyzing page nr  408
# Analyzing page nr  409
# Analyzing page nr  410
# Analyzing page nr  411
# Analyzing page nr  412
# Analyzing page nr  413
# Analyzing page nr  414
# Analyzing page nr  415
# Analyzing page nr  416
# Analyzing page nr  417
# Analyzing page nr  418
# Analyzing page nr  419
# Analyzing page nr  420
# Analyzing page nr  421
# Analyzing page nr  422
# Analyzing page nr  423
# Analyzing page nr  424
# Analyzing page nr  425
# Analyzing page nr  426
# Analyzing page nr  427
# Analyzing page nr  428
# Analyzing page nr  429
# Analyzing page nr  430
# Analyzing page nr  431
# Analyzing page nr  432
# Analyzing page nr  433
# Analyzing page nr  434
# Analyzing page nr  435
# Analyzing page nr  436
# Analyzing page nr  437
# Analyzing page nr  438
# Analyzing page nr  439
# Analyzing page nr  440
# Analyzing page nr  441
# Analyzing page nr  442
# Analyzing page nr  443
# Analyzing page nr  444
# Analyzing page nr  445
# Analyzing page nr  446
# Analyzing page nr  447
# Analyzing page nr  448
# Analyzing page nr  449
# Analyzing page nr  450
# Analyzing page nr  451
# Analyzing page nr  452
# Analyzing page nr  453
# Analyzing page nr  454
# Analyzing page nr  455
# Analyzing page nr  456
# Analyzing page nr  457
# Analyzing page nr  458
# Analyzing page nr  459
# Analyzing page nr  460
# Analyzing page nr  461
# Analyzing page nr  462
# Analyzing page nr  463
# Analyzing page nr  464
# Analyzing page nr  465
# Analyzing page nr  466
# Analyzing page nr  467
# Analyzing page nr  468
# Analyzing page nr  469
# Analyzing page nr  470
# Analyzing page nr  471
# Analyzing page nr  472
# Analyzing page nr  473
# Analyzing page nr  474
# Analyzing page nr  475
# Analyzing page nr  476
# Analyzing page nr  477
# Analyzing page nr  478
# Analyzing page nr  479
# Analyzing page nr  480
# Analyzing page nr  481
# Analyzing page nr  482
# Analyzing page nr  483
# Analyzing page nr  484
# Analyzing page nr  485
# Analyzing page nr  486
# Analyzing page nr  487
# Analyzing page nr  488
# Analyzing page nr  489
# Analyzing page nr  490
# Analyzing page nr  491
# Analyzing page nr  492
# Analyzing page nr  493
# Analyzing page nr  494
# Analyzing page nr  495
# Analyzing page nr  496
# Analyzing page nr  497
# Analyzing page nr  498
# Analyzing page nr  499
# Analyzing page nr  500
# Analyzing page nr  501
# Analyzing page nr  502
# Analyzing page nr  503
# Analyzing page nr  504
# Analyzing page nr  505
# Analyzing page nr  506
# Analyzing page nr  507
# Analyzing page nr  508
# Analyzing page nr  509
# Analyzing page nr  510
# Analyzing page nr  511
# Analyzing page nr  512
# Analyzing page nr  513
# Analyzing page nr  514
# Analyzing page nr  515
# Analyzing page nr  516
# Analyzing page nr  517
# Analyzing page nr  518
# Analyzing page nr  519
# Analyzing page nr  520
# Analyzing page nr  521
# Analyzing page nr  522
# Analyzing page nr  523
# Analyzing page nr  524
# Analyzing page nr  525
# Analyzing page nr  526
# Analyzing page nr  527
# Analyzing page nr  528
# Analyzing page nr  529
# Analyzing page nr  530
# Analyzing page nr  531
# Analyzing page nr  532
# Analyzing page nr  533
# Analyzing page nr  534
# Analyzing page nr  535
# Analyzing page nr  536
# Analyzing page nr  537
# Analyzing page nr  538
# Analyzing page nr  539
# Analyzing page nr  540
# Analyzing page nr  541
# Analyzing page nr  542
# Analyzing page nr  543
# Analyzing page nr  544
# Analyzing page nr  545
# Analyzing page nr  546
# Analyzing page nr  547
# Analyzing page nr  548
# Analyzing page nr  549
# Analyzing page nr  550
# Analyzing page nr  551
# Analyzing page nr  552
# Analyzing page nr  553
# Analyzing page nr  554
# Analyzing page nr  555
# Analyzing page nr  556
# Analyzing page nr  557
# Analyzing page nr  558
# Analyzing page nr  559
# Analyzing page nr  560
# Analyzing page nr  561
# Analyzing page nr  562
# Analyzing page nr  563
# Analyzing page nr  564
# Analyzing page nr  565
# Analyzing page nr  566
# Analyzing page nr  567
# Analyzing page nr  568
# Analyzing page nr  569
# Analyzing page nr  570
# Analyzing page nr  571
# Analyzing page nr  572
# Analyzing page nr  573
# Analyzing page nr  574
# Analyzing page nr  575
# Analyzing page nr  576
# Analyzing page nr  577
# Analyzing page nr  578
# Analyzing page nr  579
# Analyzing page nr  580
# Analyzing page nr  581
# Analyzing page nr  582
# Analyzing page nr  583
# Analyzing page nr  584
# Analyzing page nr  585
# Analyzing page nr  586
# Analyzing page nr  587
# Analyzing page nr  588
# Analyzing page nr  589
# Analyzing page nr  590
# Analyzing page nr  591
# Analyzing page nr  592
# Analyzing page nr  593
# Analyzing page nr  594
# Analyzing page nr  595
# Analyzing page nr  596
# Analyzing page nr  597
# Analyzing page nr  598
# Analyzing page nr  599
# Analyzing page nr  600
# Analyzing page nr  601
# Analyzing page nr  602
# Analyzing page nr  603
# Analyzing page nr  604
# Analyzing page nr  605
# Analyzing page nr  606
# Analyzing page nr  607
# Analyzing page nr  608
# Analyzing page nr  609
# Analyzing page nr  610
# Analyzing page nr  611
# Analyzing page nr  612
# Analyzing page nr  613
# Analyzing page nr  614
# Analyzing page nr  615
# Analyzing page nr  616
# Analyzing page nr  617
# Analyzing page nr  618
# Analyzing page nr  619
# Analyzing page nr  620
# Analyzing page nr  621
# Analyzing page nr  622
# Analyzing page nr  623
# Analyzing page nr  624
# Analyzing page nr  625
# Analyzing page nr  626
# Analyzing page nr  627
# Analyzing page nr  628
# Analyzing page nr  629
# Analyzing page nr  630
# Analyzing page nr  631
# Analyzing page nr  632
# Analyzing page nr  633
# Analyzing page nr  634
# Analyzing page nr  635
# Analyzing page nr  636
# Analyzing page nr  637
# Analyzing page nr  638
# Analyzing page nr  639
# Analyzing page nr  640
# Analyzing page nr  641
# Analyzing page nr  642
# Analyzing page nr  643
# Analyzing page nr  644
# Analyzing page nr  645
# Analyzing page nr  646
# Analyzing page nr  647
# Analyzing page nr  648
# Analyzing page nr  649
# Analyzing page nr  650
# Analyzing page nr  651
# Analyzing page nr  652
# Analyzing page nr  653
# Analyzing page nr  654
# Analyzing page nr  655
# Analyzing page nr  656
# Analyzing page nr  657
# Analyzing page nr  658
# Analyzing page nr  659
# Analyzing page nr  660
# Analyzing page nr  661
# Analyzing page nr  662
# Analyzing page nr  663
# Analyzing page nr  664
# Analyzing page nr  665
# Analyzing page nr  666
# Analyzing page nr  667
# Analyzing page nr  668
# Analyzing page nr  669
# Analyzing page nr  670
# Analyzing page nr  671
# Analyzing page nr  672
# Analyzing page nr  673
# Analyzing page nr  674
# Analyzing page nr  675
# Analyzing page nr  676
# Analyzing page nr  677
# Analyzing page nr  678
# Analyzing page nr  679
# Analyzing page nr  680
# Analyzing page nr  681
# Analyzing page nr  682
# Analyzing page nr  683
# Analyzing page nr  684
# Analyzing page nr  685
# Analyzing page nr  686
# Analyzing page nr  687
# Analyzing page nr  688
# Analyzing page nr  689
# Analyzing page nr  690
# Analyzing page nr  691
# Analyzing page nr  692
# Analyzing page nr  693
# Analyzing page nr  694
# Analyzing page nr  695
# Analyzing page nr  696
# Analyzing page nr  697
# Analyzing page nr  698
# Analyzing page nr  699
# Analyzing page nr  700
# Analyzing page nr  701
# Analyzing page nr  702
# Analyzing page nr  703
# Analyzing page nr  704
# Analyzing page nr  705
# Analyzing page nr  706
# Analyzing page nr  707
# Analyzing page nr  708
# Analyzing page nr  709
# Analyzing page nr  710
# Analyzing page nr  711
# Analyzing page nr  712
# Analyzing page nr  713
# Analyzing page nr  714
# Analyzing page nr  715
# Analyzing page nr  716
# Analyzing page nr  717
# Analyzing page nr  718
# Analyzing page nr  719
# Analyzing page nr  720
# Analyzing page nr  721
# Analyzing page nr  722
# Analyzing page nr  723
# Analyzing page nr  724
# Analyzing page nr  725
# Analyzing page nr  726
# Analyzing page nr  727
# Analyzing page nr  728
# Analyzing page nr  729
# Analyzing page nr  730
# Analyzing page nr  731
# Analyzing page nr  732
# Analyzing page nr  733
# Analyzing page nr  734
# Analyzing page nr  735
# Analyzing page nr  736
# Analyzing page nr  737
# Analyzing page nr  738
# Analyzing page nr  739
# Analyzing page nr  740
# Analyzing page nr  741
# Analyzing page nr  742
# Analyzing page nr  743
# Analyzing page nr  744
# Analyzing page nr  745
# Analyzing page nr  746
# Analyzing page nr  747
# Analyzing page nr  748
# Analyzing page nr  749
# Analyzing page nr  750
# Analyzing page nr  751
# Analyzing page nr  752
# Analyzing page nr  753
# Analyzing page nr  754
# Analyzing page nr  755
# Analyzing page nr  756
# Analyzing page nr  757
# Analyzing page nr  758
# Analyzing page nr  759
# Analyzing page nr  760
# Analyzing page nr  761
# Analyzing page nr  762
# Analyzing page nr  763
# Analyzing page nr  764
# Analyzing page nr  765
# Analyzing page nr  766
# Analyzing page nr  767
# Analyzing page nr  768
# Analyzing page nr  769
# Analyzing page nr  770
# Analyzing page nr  771
# Analyzing page nr  772
# Analyzing page nr  773
# Analyzing page nr  774
# Analyzing page nr  775
# Analyzing page nr  776
# Analyzing page nr  777
# Analyzing page nr  778
# Analyzing page nr  779
# Analyzing page nr  780
# Analyzing page nr  781
# Analyzing page nr  782
# Analyzing page nr  783
# Analyzing page nr  784
# Analyzing page nr  785
# Analyzing page nr  786
# Analyzing page nr  787
# Analyzing page nr  788
# Analyzing page nr  789
# Analyzing page nr  790
# Analyzing page nr  791
# Analyzing page nr  792
# Analyzing page nr  793
# Analyzing page nr  794
# Analyzing page nr  795
# Analyzing page nr  796
# Analyzing page nr  797
# Analyzing page nr  798
# Analyzing page nr  799
# Analyzing page nr  800
# Analyzing page nr  801
# Analyzing page nr  802
# Analyzing page nr  803
# Analyzing page nr  804
# Analyzing page nr  805
# Analyzing page nr  806
# Analyzing page nr  807
# Analyzing page nr  808
# Analyzing page nr  809
# Analyzing page nr  810
# Analyzing page nr  811
# Analyzing page nr  812
# Analyzing page nr  813
# Analyzing page nr  814
# Analyzing page nr  815
# Analyzing page nr  816
# Analyzing page nr  817
# Analyzing page nr  818
# Analyzing page nr  819
# Analyzing page nr  820
# Analyzing page nr  821
# Analyzing page nr  822
# Analyzing page nr  823
# Analyzing page nr  824
# Analyzing page nr  825
# Analyzing page nr  826
# Analyzing page nr  827
# Analyzing page nr  828
# Analyzing page nr  829
# Analyzing page nr  830
# Analyzing page nr  831
# Analyzing page nr  832
# Analyzing page nr  833
# Analyzing page nr  834
# Analyzing page nr  835
# Analyzing page nr  836
# Analyzing page nr  837
# Analyzing page nr  838
# Analyzing page nr  839
# Analyzing page nr  840
# Analyzing page nr  841
# Analyzing page nr  842
# Analyzing page nr  843
# Analyzing page nr  844
# Analyzing page nr  845
# Analyzing page nr  846
# Analyzing page nr  847
# Analyzing page nr  848
# Analyzing page nr  849
# Analyzing page nr  850
# Analyzing page nr  851
# Analyzing page nr  852
# Analyzing page nr  853
# Analyzing page nr  854
# Analyzing page nr  855
# Analyzing page nr  856
# Analyzing page nr  857
# Analyzing page nr  858
# Analyzing page nr  859
# Analyzing page nr  860
# Analyzing page nr  861
# Analyzing page nr  862
# Analyzing page nr  863
# Analyzing page nr  864
# Analyzing page nr  865
# Analyzing page nr  866
# Analyzing page nr  867
# Analyzing page nr  868
# Analyzing page nr  869
# Analyzing page nr  870
# Analyzing page nr  871
# Analyzing page nr  872
# Analyzing page nr  873
# Analyzing page nr  874
# Analyzing page nr  875
# Analyzing page nr  876
# Analyzing page nr  877
# Analyzing page nr  878
# Analyzing page nr  879
# Analyzing page nr  880
# Analyzing page nr  881
# Analyzing page nr  882
# Analyzing page nr  883
# Analyzing page nr  884
# Analyzing page nr  885
# Analyzing page nr  886
# Analyzing page nr  887
# Analyzing page nr  888
# Analyzing page nr  889
# Analyzing page nr  890
# Analyzing page nr  891
# Analyzing page nr  892
# Analyzing page nr  893
# Analyzing page nr  894
# Analyzing page nr  895
# Analyzing page nr  896
# Analyzing page nr  897
# Analyzing page nr  898
# Analyzing page nr  899
# Analyzing page nr  900
# Analyzing page nr  901
# Analyzing page nr  902
# Analyzing page nr  903
# Analyzing page nr  904
# Analyzing page nr  905
# Analyzing page nr  906
# Analyzing page nr  907
# Analyzing page nr  908
# Analyzing page nr  909
# Analyzing page nr  910
# Analyzing page nr  911
# Analyzing page nr  912
# Analyzing page nr  913
# Analyzing page nr  914
# Analyzing page nr  915
# Analyzing page nr  916
# Analyzing page nr  917
# Analyzing page nr  918
# Analyzing page nr  919
# Analyzing page nr  920
# Analyzing page nr  921
# Analyzing page nr  922
# Analyzing page nr  923
# Analyzing page nr  924
# Analyzing page nr  925
# Analyzing page nr  926
# Analyzing page nr  927
# Analyzing page nr  928
# Analyzing page nr  929
# Analyzing page nr  930
# Analyzing page nr  931
# Analyzing page nr  932
# Analyzing page nr  933
# Analyzing page nr  934
# Analyzing page nr  935
# Analyzing page nr  936
# Analyzing page nr  937
# Analyzing page nr  938
# Analyzing page nr  939
# Analyzing page nr  940
# Analyzing page nr  941
# Analyzing page nr  942
# Analyzing page nr  943
# Analyzing page nr  944
# Analyzing page nr  945
# Analyzing page nr  946
# Analyzing page nr  947
# Analyzing page nr  948
# Analyzing page nr  949
# Analyzing page nr  950
# Analyzing page nr  951
# Analyzing page nr  952
# Analyzing page nr  953
# Analyzing page nr  954
# Analyzing page nr  955
# Analyzing page nr  956
# Analyzing page nr  957
# Analyzing page nr  958
# Analyzing page nr  959
# Analyzing page nr  960
# Analyzing page nr  961
# Analyzing page nr  962
# Analyzing page nr  963
# Analyzing page nr  964
# Analyzing page nr  965
# Analyzing page nr  966
# Analyzing page nr  967
# Analyzing page nr  968
# Analyzing page nr  969
# Analyzing page nr  970
# Analyzing page nr  971
# Analyzing page nr  972
# Analyzing page nr  973
# Analyzing page nr  974
# Analyzing page nr  975
# Analyzing page nr  976
# Analyzing page nr  977
# Analyzing page nr  978
# Analyzing page nr  979
# Analyzing page nr  980
# Analyzing page nr  981
# Analyzing page nr  982
# Analyzing page nr  983
# Analyzing page nr  984
# Analyzing page nr  985
# Analyzing page nr  986
# Analyzing page nr  987
# Analyzing page nr  988
# Analyzing page nr  989
# Analyzing page nr  990
# Analyzing page nr  991
# Analyzing page nr  992
# Analyzing page nr  993
# Analyzing page nr  994
# Analyzing page nr  995
# Analyzing page nr  996
# Analyzing page nr  997
# Analyzing page nr  998
# Analyzing page nr  999
# Analyzing page nr  1000
# Analyzing page nr  1001
# Analyzing page nr  1002
# Analyzing page nr  1003
# Analyzing page nr  1004
# Analyzing page nr  1005
# Analyzing page nr  1006
# Analyzing page nr  1007
# Analyzing page nr  1008
# Analyzing page nr  1009
# Analyzing page nr  1010
# Analyzing page nr  1011
# Analyzing page nr  1012
# Analyzing page nr  1013
# Analyzing page nr  1014
# Analyzing page nr  1015
# Analyzing page nr  1016
# Analyzing page nr  1017
# Analyzing page nr  1018
# Analyzing page nr  1019
# Analyzing page nr  1020
# Analyzing page nr  1021
# Analyzing page nr  1022
# Analyzing page nr  1023
# Analyzing page nr  1024
# Analyzing page nr  1025
# Analyzing page nr  1026
# Analyzing page nr  1027
# Analyzing page nr  1028
# Analyzing page nr  1029
# Analyzing page nr  1030
# Analyzing page nr  1031
# Analyzing page nr  1032
# Analyzing page nr  1033
# Analyzing page nr  1034
# Analyzing page nr  1035
# Analyzing page nr  1036
# Analyzing page nr  1037
# Analyzing page nr  1038
# Analyzing page nr  1039
# Analyzing page nr  1040
# Analyzing page nr  1041
# Analyzing page nr  1042
# Analyzing page nr  1043
# Analyzing page nr  1044
# Analyzing page nr  1045
# Analyzing page nr  1046
# Analyzing page nr  1047
# Analyzing page nr  1048
# Analyzing page nr  1049
# Analyzing page nr  1050
# Analyzing page nr  1051
# Analyzing page nr  1052
# Analyzing page nr  1053
# Analyzing page nr  1054
# Analyzing page nr  1055
# Analyzing page nr  1056
# Analyzing page nr  1057
# Analyzing page nr  1058
# Analyzing page nr  1059
# Analyzing page nr  1060
# Analyzing page nr  1061
# Analyzing page nr  1062
# Analyzing page nr  1063
# Analyzing page nr  1064
# Analyzing page nr  1065
# Analyzing page nr  1066
# Analyzing page nr  1067
# Analyzing page nr  1068
# Analyzing page nr  1069
# Analyzing page nr  1070
# Analyzing page nr  1071
# Analyzing page nr  1072
# Analyzing page nr  1073
# Analyzing page nr  1074
# Analyzing page nr  1075
# Analyzing page nr  1076
# Analyzing page nr  1077
# Analyzing page nr  1078
# Analyzing page nr  1079
# Analyzing page nr  1080
# Analyzing page nr  1081
# Analyzing page nr  1082
# Analyzing page nr  1083
# Analyzing page nr  1084
# Analyzing page nr  1085
# Analyzing page nr  1086
# Analyzing page nr  1087
# Analyzing page nr  1088
# Analyzing page nr  1089
# Analyzing page nr  1090
# Analyzing page nr  1091
# Analyzing page nr  1092
# Analyzing page nr  1093
# Analyzing page nr  1094
# Analyzing page nr  1095
# Analyzing page nr  1096
# Analyzing page nr  1097
# Analyzing page nr  1098
# Analyzing page nr  1099
# Analyzing page nr  1100
# Analyzing page nr  1101
# Analyzing page nr  1102
# Analyzing page nr  1103
# Analyzing page nr  1104
# Analyzing page nr  1105
# Analyzing page nr  1106
# Analyzing page nr  1107
# Analyzing page nr  1108
# Analyzing page nr  1109
# Analyzing page nr  1110
# Analyzing page nr  1111
# Analyzing page nr  1112
# Analyzing page nr  1113
# Analyzing page nr  1114
# Analyzing page nr  1115
# Analyzing page nr  1116
# Analyzing page nr  1117
# Analyzing page nr  1118
# Analyzing page nr  1119
# Analyzing page nr  1120
# Analyzing page nr  1121
# Analyzing page nr  1122
# Analyzing page nr  1123
# Analyzing page nr  1124
# Analyzing page nr  1125
# Analyzing page nr  1126
# Analyzing page nr  1127
# Analyzing page nr  1128
# Analyzing page nr  1129
# Analyzing page nr  1130
# Analyzing page nr  1131
# Analyzing page nr  1132
# Analyzing page nr  1133
# Analyzing page nr  1134
# Analyzing page nr  1135
# Analyzing page nr  1136
# Analyzing page nr  1137
# Analyzing page nr  1138
# Analyzing page nr  1139
# Analyzing page nr  1140
# Analyzing page nr  1141
# Analyzing page nr  1142
# Analyzing page nr  1143
# Analyzing page nr  1144
# Analyzing page nr  1145
# Analyzing page nr  1146
# Analyzing page nr  1147
# Analyzing page nr  1148
# Analyzing page nr  1149
# Analyzing page nr  1150
# Analyzing page nr  1151
# Analyzing page nr  1152
# Analyzing page nr  1153
# Analyzing page nr  1154
# Analyzing page nr  1155
# Analyzing page nr  1156
# Analyzing page nr  1157
# Analyzing page nr  1158
# Analyzing page nr  1159
# Analyzing page nr  1160
# Analyzing page nr  1161
# Analyzing page nr  1162
# Analyzing page nr  1163
# Analyzing page nr  1164
# Analyzing page nr  1165
# Analyzing page nr  1166
# Analyzing page nr  1167
# Analyzing page nr  1168
# Analyzing page nr  1169
# Analyzing page nr  1170
# Analyzing page nr  1171
# Analyzing page nr  1172
# Analyzing page nr  1173
# Analyzing page nr  1174
# Analyzing page nr  1175
# Analyzing page nr  1176
# Analyzing page nr  1177
# Analyzing page nr  1178
# Analyzing page nr  1179
# Analyzing page nr  1180
# Analyzing page nr  1181
# Analyzing page nr  1182
# Analyzing page nr  1183
# Analyzing page nr  1184
# Analyzing page nr  1185
# Analyzing page nr  1186
# Analyzing page nr  1187
# Analyzing page nr  1188
# Analyzing page nr  1189
# Analyzing page nr  1190
# Analyzing page nr  1191
# Analyzing page nr  1192
# Analyzing page nr  1193
# Analyzing page nr  1194
# Analyzing page nr  1195
# Analyzing page nr  1196
# Analyzing page nr  1197
# Analyzing page nr  1198
# Analyzing page nr  1199
# Analyzing page nr  1200
# Analyzing page nr  1201
# Analyzing page nr  1202
# Analyzing page nr  1203
# Analyzing page nr  1204
# Analyzing page nr  1205
# Analyzing page nr  1206
# Analyzing page nr  1207
# Analyzing page nr  1208
# Analyzing page nr  1209
# Analyzing page nr  1210
# Analyzing page nr  1211
# Analyzing page nr  1212
# Analyzing page nr  1213
# Analyzing page nr  1214
# Analyzing page nr  1215
# Analyzing page nr  1216
# Analyzing page nr  1217
# Analyzing page nr  1218
# Analyzing page nr  1219
# Analyzing page nr  1220
# Analyzing page nr  1221
# Analyzing page nr  1222
# Analyzing page nr  1223
# Analyzing page nr  1224
# Analyzing page nr  1225
# Analyzing page nr  1226
# Analyzing page nr  1227
# Analyzing page nr  1228
# Analyzing page nr  1229
# Analyzing page nr  1230
# Analyzing page nr  1231
# Analyzing page nr  1232
# Analyzing page nr  1233
# Analyzing page nr  1234
# Analyzing page nr  1235
# Analyzing page nr  1236
# Analyzing page nr  1237
# Analyzing page nr  1238
# Analyzing page nr  1239
# Analyzing page nr  1240
# Analyzing page nr  1241
# Analyzing page nr  1242
# Analyzing page nr  1243
# Analyzing page nr  1244
# Analyzing page nr  1245
# Analyzing page nr  1246
# Analyzing page nr  1247
# Analyzing page nr  1248
# Analyzing page nr  1249
# Analyzing page nr  1250
# Analyzing page nr  1251
# Analyzing page nr  1252
# Analyzing page nr  1253
# Analyzing page nr  1254
# Analyzing page nr  1255
# Analyzing page nr  1256
# Analyzing page nr  1257
# Analyzing page nr  1258
# Analyzing page nr  1259
# Analyzing page nr  1260
# Analyzing page nr  1261
# Analyzing page nr  1262
# Analyzing page nr  1263
# Analyzing page nr  1264
# Analyzing page nr  1265
# Analyzing page nr  1266
# Analyzing page nr  1267
# Analyzing page nr  1268
# Analyzing page nr  1269
# Analyzing page nr  1270
# Analyzing page nr  1271
# Analyzing page nr  1272
# Analyzing page nr  1273
# Analyzing page nr  1274
# Analyzing page nr  1275
# Analyzing page nr  1276
# Analyzing page nr  1277
# Analyzing page nr  1278
# Analyzing page nr  1279
# Analyzing page nr  1280
# Analyzing page nr  1281
# Analyzing page nr  1282
# Analyzing page nr  1283
# Analyzing page nr  1284
# Analyzing page nr  1285
# Analyzing page nr  1286
# Analyzing page nr  1287
# Analyzing page nr  1288
# Analyzing page nr  1289
# Analyzing page nr  1290
# Analyzing page nr  1291
# Analyzing page nr  1292
# Analyzing page nr  1293
# Analyzing page nr  1294
# Analyzing page nr  1295
# Analyzing page nr  1296
# Analyzing page nr  1297
# Analyzing page nr  1298
# Analyzing page nr  1299
# Analyzing page nr  1300
# Analyzing page nr  1301
# Analyzing page nr  1302
# Analyzing page nr  1303
# Analyzing page nr  1304
# Analyzing page nr  1305
# Analyzing page nr  1306
# Analyzing page nr  1307
# Analyzing page nr  1308
# Analyzing page nr  1309
# Analyzing page nr  1310
# Analyzing page nr  1311
# Analyzing page nr  1312
# Analyzing page nr  1313
# Analyzing page nr  1314
# Analyzing page nr  1315
# Analyzing page nr  1316
# Analyzing page nr  1317
# Analyzing page nr  1318
# Analyzing page nr  1319
# Analyzing page nr  1320
# Analyzing page nr  1321
# Analyzing page nr  1322
# Analyzing page nr  1323
# Analyzing page nr  1324
# Analyzing page nr  1325
# Analyzing page nr  1326
# Analyzing page nr  1327
# Analyzing page nr  1328
# Analyzing page nr  1329
# Analyzing page nr  1330
# Analyzing page nr  1331
# Analyzing page nr  1332
# Analyzing page nr  1333
# Analyzing page nr  1334
# Analyzing page nr  1335
# Analyzing page nr  1336
# Analyzing page nr  1337
# Analyzing page nr  1338
# Analyzing page nr  1339
# Analyzing page nr  1340
# Analyzing page nr  1341
# Analyzing page nr  1342
# Analyzing page nr  1343
# Analyzing page nr  1344
# Analyzing page nr  1345
# Analyzing page nr  1346
# Analyzing page nr  1347
# Analyzing page nr  1348
# Analyzing page nr  1349
# Analyzing page nr  1350
# Analyzing page nr  1351
# Analyzing page nr  1352
# Analyzing page nr  1353
# Analyzing page nr  1354
# Analyzing page nr  1355
# Analyzing page nr  1356
# Analyzing page nr  1357
# Analyzing page nr  1358
# Analyzing page nr  1359
# Analyzing page nr  1360
# Analyzing page nr  1361
# Analyzing page nr  1362
# Analyzing page nr  1363
# Analyzing page nr  1364
# Analyzing page nr  1365
# Analyzing page nr  1366
# Analyzing page nr  1367
# Analyzing page nr  1368
# Analyzing page nr  1369
# Analyzing page nr  1370
# Analyzing page nr  1371
# Analyzing page nr  1372
# Analyzing page nr  1373
# Analyzing page nr  1374
# Analyzing page nr  1375
# Analyzing page nr  1376
# Analyzing page nr  1377
# Analyzing page nr  1378
# Analyzing page nr  1379
# Analyzing page nr  1380
# Analyzing page nr  1381
# Analyzing page nr  1382
# Analyzing page nr  1383
# Analyzing page nr  1384
# Analyzing page nr  1385
# Analyzing page nr  1386
# Analyzing page nr  1387
# Analyzing page nr  1388
# Analyzing page nr  1389
# Analyzing page nr  1390
# Analyzing page nr  1391
# Analyzing page nr  1392
# Analyzing page nr  1393
# Analyzing page nr  1394
# Analyzing page nr  1395
# Analyzing page nr  1396
# Analyzing page nr  1397
# Analyzing page nr  1398
# Analyzing page nr  1399
# Analyzing page nr  1400
# Analyzing page nr  1401
# Analyzing page nr  1402
# Analyzing page nr  1403
# Analyzing page nr  1404
# Analyzing page nr  1405
# Analyzing page nr  1406
# Analyzing page nr  1407
# Analyzing page nr  1408
# Analyzing page nr  1409
# Analyzing page nr  1410
# Analyzing page nr  1411
# Analyzing page nr  1412
# Analyzing page nr  1413
# Analyzing page nr  1414
# Analyzing page nr  1415
# Analyzing page nr  1416
# Analyzing page nr  1417
# Analyzing page nr  1418
# Analyzing page nr  1419
# Analyzing page nr  1420
# Analyzing page nr  1421
# Analyzing page nr  1422
# Analyzing page nr  1423
# Analyzing page nr  1424
# Analyzing page nr  1425
# Analyzing page nr  1426
# Analyzing page nr  1427
# Analyzing page nr  1428
# Analyzing page nr  1429
# Analyzing page nr  1430
# Analyzing page nr  1431
# Analyzing page nr  1432
# Analyzing page nr  1433
# Analyzing page nr  1434
# Analyzing page nr  1435
# Analyzing page nr  1436
# Analyzing page nr  1437
# Analyzing page nr  1438
# Analyzing page nr  1439
# Analyzing page nr  1440
# Analyzing page nr  1441
# Analyzing page nr  1442
# Analyzing page nr  1443
# Analyzing page nr  1444
# Analyzing page nr  1445
# Analyzing page nr  1446
# Analyzing page nr  1447
# Analyzing page nr  1448
# Analyzing page nr  1449
# Analyzing page nr  1450
# Analyzing page nr  1451
# Analyzing page nr  1452
# Analyzing page nr  1453
# Analyzing page nr  1454
# Analyzing page nr  1455
# Analyzing page nr  1456
# Analyzing page nr  1457
# Analyzing page nr  1458
# Analyzing page nr  1459
# Analyzing page nr  1460
# Analyzing page nr  1461
# Analyzing page nr  1462
# Analyzing page nr  1463
# Analyzing page nr  1464
# Analyzing page nr  1465
# Analyzing page nr  1466
# Analyzing page nr  1467
# Analyzing page nr  1468
# Analyzing page nr  1469
# Analyzing page nr  1470
# Analyzing page nr  1471
# Analyzing page nr  1472
# Analyzing page nr  1473
# Analyzing page nr  1474
# Analyzing page nr  1475
# Analyzing page nr  1476
# Analyzing page nr  1477
# Analyzing page nr  1478
# Analyzing page nr  1479
# Analyzing page nr  1480
# Analyzing page nr  1481
# Analyzing page nr  1482
# Analyzing page nr  1483
# Analyzing page nr  1484
# Analyzing page nr  1485
# Analyzing page nr  1486
# Analyzing page nr  1487
# Analyzing page nr  1488
# Analyzing page nr  1489
# Analyzing page nr  1490
# Analyzing page nr  1491
# Analyzing page nr  1492
# Analyzing page nr  1493
# Analyzing page nr  1494
# Analyzing page nr  1495
# Analyzing page nr  1496
# Analyzing page nr  1497
# Analyzing page nr  1498
# Analyzing page nr  1499
# Analyzing page nr  1500
# Analyzing page nr  1501
# Analyzing page nr  1502
# Analyzing page nr  1503
# Analyzing page nr  1504
# Analyzing page nr  1505
# Analyzing page nr  1506
# Analyzing page nr  1507
# Analyzing page nr  1508
# Analyzing page nr  1509
# Analyzing page nr  1510
# Analyzing page nr  1511
# Analyzing page nr  1512
# Analyzing page nr  1513
# Analyzing page nr  1514
# Analyzing page nr  1515
# Analyzing page nr  1516
# Analyzing page nr  1517
# Analyzing page nr  1518
# Analyzing page nr  1519
# Analyzing page nr  1520
# Analyzing page nr  1521
# Analyzing page nr  1522
# Analyzing page nr  1523
# Analyzing page nr  1524
# Analyzing page nr  1525
# Analyzing page nr  1526
# Analyzing page nr  1527
# Analyzing page nr  1528
# Analyzing page nr  1529
# Analyzing page nr  1530
# Analyzing page nr  1531
# Analyzing page nr  1532
# Analyzing page nr  1533
# Analyzing page nr  1534
# Analyzing page nr  1535
# Analyzing page nr  1536
# Analyzing page nr  1537
# Analyzing page nr  1538
# Analyzing page nr  1539
# Analyzing page nr  1540
# Analyzing page nr  1541
# Analyzing page nr  1542
# Analyzing page nr  1543
# Analyzing page nr  1544
# Analyzing page nr  1545
# Analyzing page nr  1546
# Analyzing page nr  1547
# Analyzing page nr  1548
# Analyzing page nr  1549
# Analyzing page nr  1550
# Analyzing page nr  1551
# Analyzing page nr  1552
# Analyzing page nr  1553
# Analyzing page nr  1554
# Analyzing page nr  1555
# Analyzing page nr  1556
# Analyzing page nr  1557
# Analyzing page nr  1558
# Analyzing page nr  1559
# Analyzing page nr  1560
# Analyzing page nr  1561
# Analyzing page nr  1562
# Analyzing page nr  1563
# Analyzing page nr  1564
# Analyzing page nr  1565
# Analyzing page nr  1566
# Analyzing page nr  1567
# Analyzing page nr  1568
# Analyzing page nr  1569
# Analyzing page nr  1570
# Analyzing page nr  1571
# Analyzing page nr  1572
# Analyzing page nr  1573
# Analyzing page nr  1574
# Analyzing page nr  1575
# Analyzing page nr  1576
# Analyzing page nr  1577
# Analyzing page nr  1578
# Analyzing page nr  1579
# Analyzing page nr  1580
# Analyzing page nr  1581
# Analyzing page nr  1582
# Analyzing page nr  1583
# Analyzing page nr  1584
# Analyzing page nr  1585
# Analyzing page nr  1586
# Analyzing page nr  1587
# Analyzing page nr  1588
# Analyzing page nr  1589
# Analyzing page nr  1590
# Analyzing page nr  1591
# Analyzing page nr  1592
# Analyzing page nr  1593
# Analyzing page nr  1594
# Analyzing page nr  1595
# Analyzing page nr  1596
# Analyzing page nr  1597
# Analyzing page nr  1598
# Analyzing page nr  1599
# Analyzing page nr  1600
# Analyzing page nr  1601
# Analyzing page nr  1602
# Analyzing page nr  1603
# Analyzing page nr  1604
# Analyzing page nr  1605
# Analyzing page nr  1606
# Analyzing page nr  1607
# Analyzing page nr  1608
# Analyzing page nr  1609
# Analyzing page nr  1610
# Analyzing page nr  1611
# Analyzing page nr  1612
# Analyzing page nr  1613
# Analyzing page nr  1614
# Analyzing page nr  1615
# Analyzing page nr  1616
# Analyzing page nr  1617
# Analyzing page nr  1618
# Analyzing page nr  1619
# Analyzing page nr  1620
# Analyzing page nr  1621
# Analyzing page nr  1622
# Analyzing page nr  1623
# Analyzing page nr  1624
# Analyzing page nr  1625
# Analyzing page nr  1626
# Analyzing page nr  1627
# Analyzing page nr  1628
# Analyzing page nr  1629
# Analyzing page nr  1630
# Analyzing page nr  1631
# Analyzing page nr  1632
# Analyzing page nr  1633
# Analyzing page nr  1634
# Analyzing page nr  1635
# Analyzing page nr  1636
# Analyzing page nr  1637
# Analyzing page nr  1638
# Analyzing page nr  1639
# Analyzing page nr  1640
# Analyzing page nr  1641
# Analyzing page nr  1642
# Analyzing page nr  1643
# Analyzing page nr  1644
# Analyzing page nr  1645
# Analyzing page nr  1646
# Analyzing page nr  1647
# Analyzing page nr  1648
# Analyzing page nr  1649
# Analyzing page nr  1650
# Analyzing page nr  1651
# Analyzing page nr  1652
# Analyzing page nr  1653
# Analyzing page nr  1654
# Analyzing page nr  1655
# Analyzing page nr  1656
# Analyzing page nr  1657
# Analyzing page nr  1658
# Analyzing page nr  1659
# Analyzing page nr  1660
# Analyzing page nr  1661
# Analyzing page nr  1662
# Analyzing page nr  1663
# Analyzing page nr  1664
# Analyzing page nr  1665
# Analyzing page nr  1666
# Analyzing page nr  1667
# Analyzing page nr  1668
# Analyzing page nr  1669
# Analyzing page nr  1670
# Analyzing page nr  1671
# Analyzing page nr  1672
# Analyzing page nr  1673
# Analyzing page nr  1674
# Analyzing page nr  1675
# Analyzing page nr  1676
# Analyzing page nr  1677
# Analyzing page nr  1678
# Analyzing page nr  1679
# Analyzing page nr  1680
# Analyzing page nr  1681
# Analyzing page nr  1682
# Analyzing page nr  1683
# Analyzing page nr  1684
# Analyzing page nr  1685
# Analyzing page nr  1686
# Analyzing page nr  1687
# Analyzing page nr  1688
# Analyzing page nr  1689
# Analyzing page nr  1690
# Analyzing page nr  1691
# Analyzing page nr  1692
# Analyzing page nr  1693
# Analyzing page nr  1694
# Analyzing page nr  1695
# Analyzing page nr  1696
# Analyzing page nr  1697
# Analyzing page nr  1698
# Analyzing page nr  1699
# Analyzing page nr  1700
# Analyzing page nr  1701
# Analyzing page nr  1702
# Analyzing page nr  1703
# Analyzing page nr  1704
# Analyzing page nr  1705
# Analyzing page nr  1706
# Analyzing page nr  1707
# Analyzing page nr  1708
# Analyzing page nr  1709
# Analyzing page nr  1710
# Analyzing page nr  1711
# Analyzing page nr  1712
# Analyzing page nr  1713
# Analyzing page nr  1714
# Analyzing page nr  1715
# Analyzing page nr  1716
# Analyzing page nr  1717
# Analyzing page nr  1718
# Analyzing page nr  1719
# Analyzing page nr  1720
# Analyzing page nr  1721
# Analyzing page nr  1722
# Analyzing page nr  1723
# Analyzing page nr  1724
# Analyzing page nr  1725
# Analyzing page nr  1726
# Analyzing page nr  1727
# Analyzing page nr  1728
# Analyzing page nr  1729
# Analyzing page nr  1730
# Analyzing page nr  1731
# Analyzing page nr  1732
# Analyzing page nr  1733
# Analyzing page nr  1734
# Analyzing page nr  1735
# Analyzing page nr  1736
# Analyzing page nr  1737
# Analyzing page nr  1738
# Analyzing page nr  1739
# Analyzing page nr  1740
# Analyzing page nr  1741
# Analyzing page nr  1742
# Analyzing page nr  1743
# Analyzing page nr  1744
# Analyzing page nr  1745
# Analyzing page nr  1746
# Analyzing page nr  1747
# Analyzing page nr  1748
# Analyzing page nr  1749
# Analyzing page nr  1750
# Analyzing page nr  1751
# Analyzing page nr  1752
# Analyzing page nr  1753
# Analyzing page nr  1754
# Analyzing page nr  1755
# Analyzing page nr  1756
# Analyzing page nr  1757
# Analyzing page nr  1758
# Analyzing page nr  1759
# Analyzing page nr  1760
# Analyzing page nr  1761
# Analyzing page nr  1762
# Analyzing page nr  1763
# Analyzing page nr  1764
# Analyzing page nr  1765
# Analyzing page nr  1766
# Analyzing page nr  1767
# Analyzing page nr  1768
# Analyzing page nr  1769
# Analyzing page nr  1770
# Analyzing page nr  1771
# Analyzing page nr  1772
# Analyzing page nr  1773
# Analyzing page nr  1774
# Analyzing page nr  1775
# Analyzing page nr  1776
# Analyzing page nr  1777
# Analyzing page nr  1778
# Analyzing page nr  1779
# Analyzing page nr  1780
# Analyzing page nr  1781
# Analyzing page nr  1782
# Analyzing page nr  1783
# Analyzing page nr  1784
# Analyzing page nr  1785
# Analyzing page nr  1786
# Analyzing page nr  1787
# Analyzing page nr  1788
# Analyzing page nr  1789
# Analyzing page nr  1790
# Analyzing page nr  1791
# Analyzing page nr  1792
# Analyzing page nr  1793
# Analyzing page nr  1794
# Analyzing page nr  1795
# Analyzing page nr  1796
# Analyzing page nr  1797
# Analyzing page nr  1798
# Analyzing page nr  1799
# Analyzing page nr  1800
# Analyzing page nr  1801
# Analyzing page nr  1802
# Analyzing page nr  1803
# Analyzing page nr  1804
# Analyzing page nr  1805
# Analyzing page nr  1806
# Analyzing page nr  1807
# Analyzing page nr  1808
# Analyzing page nr  1809
# Analyzing page nr  1810
# Analyzing page nr  1811
# Analyzing page nr  1812
# Analyzing page nr  1813
# Analyzing page nr  1814
# Analyzing page nr  1815
# Analyzing page nr  1816
# Analyzing page nr  1817
# Analyzing page nr  1818
# Analyzing page nr  1819
# Analyzing page nr  1820
# Analyzing page nr  1821
# Analyzing page nr  1822
# Analyzing page nr  1823
# Analyzing page nr  1824
# Analyzing page nr  1825
# Analyzing page nr  1826
# Analyzing page nr  1827
# Analyzing page nr  1828
# Analyzing page nr  1829
# We gathered 17580 statements

# %%
df_statement = pd.DataFrame(statements)

# %%
df_statement.head()
# Out:
#                                                claim        claimant  \
# 0  Kamala Harris said, "I don't like Joe Biden an...  Facebook posts
# 1  Condoleezza Rice said, "If you are taught bitt...  Facebook posts
# 2  A coloring book that describes Joe Biden as "A...     Viral image
# 3  "In West Virginia alone, overdoses have increa...    Carol Miller
# 4  The United States is "the only major industria...    Bill Clinton
#
#                                                  url reviewDate       Rating  \
# 0  https://www.politifact.com/factchecks/2020/aug... 2020-08-19        false
# 1  https://www.politifact.com/factchecks/2020/aug... 2020-08-19    half-true
# 2  https://www.politifact.com/factchecks/2020/aug... 2020-08-19        false
# 3  https://www.politifact.com/factchecks/2020/aug... 2020-08-19  mostly-true
# 4  https://www.politifact.com/factchecks/2020/aug... 2020-08-18  mostly-true
#
#   languageCode publisherName   publisherSite claimLink
# 0           en    Politifact  politifact.com       NaN
# 1           en    Politifact  politifact.com       NaN
# 2           en    Politifact  politifact.com       NaN
# 3           en    Politifact  politifact.com       NaN
# 4           en    Politifact  politifact.com       NaN

# %% [markdown]
# Now we need to make add a uniform rating

# %%
print("Unique ratings: ", df_statement['Rating'].unique().tolist())
# Out:
# Unique ratings:  ['false', 'half-true', 'mostly-true', 'pants-fire', 'true', 'barely-true', 'full-flop', 'half-flip', 'no-flip']

# %% [markdown]
# We drop claims with ratings "full-flop", "half-flip", "no-flip" as they refer to change on stances by politicians, so the fact-checking article won't be supporting or refuting the claim, but rather denouncing this change.

# %%
print("Original length: ", len(df_statement))
df_statement = df_statement[~df_statement['Rating'].isin(['full-flop', 'half-flip', 'no-flip'])]
print("New length: ", len(df_statement))
# Out:
# Original length:  17580
# New length:  17338

# %%
def uniform_rating(rating):
    simplified_ratings = ["False", "Mostly False", "Exaggerated", "Half True or Out of Context", "Mostly True", "True"]
    if rating in ['false', 'pants-fire']:
        return simplified_ratings[0]
    if rating in ['barely-true']:
        return simplified_ratings[1]
    if rating in ['half-true']:
        return simplified_ratings[3]
    if rating in ['mostly-true']:
        return simplified_ratings[4]
    if rating in ['true']:
        return simplified_ratings[5]

df_statement['UniformRating'] = df_statement['Rating'].apply(uniform_rating)

# %%
df_statement.head()
# Out:
#                                                claim        claimant  \
# 0  Kamala Harris said, "I don't like Joe Biden an...  Facebook posts
# 1  Condoleezza Rice said, "If you are taught bitt...  Facebook posts
# 2  A coloring book that describes Joe Biden as "A...     Viral image
# 3  "In West Virginia alone, overdoses have increa...    Carol Miller
# 4  The United States is "the only major industria...    Bill Clinton
#
#                                                  url reviewDate       Rating  \
# 0  https://www.politifact.com/factchecks/2020/aug... 2020-08-19        false
# 1  https://www.politifact.com/factchecks/2020/aug... 2020-08-19    half-true
# 2  https://www.politifact.com/factchecks/2020/aug... 2020-08-19        false
# 3  https://www.politifact.com/factchecks/2020/aug... 2020-08-19  mostly-true
# 4  https://www.politifact.com/factchecks/2020/aug... 2020-08-18  mostly-true
#
#   languageCode publisherName   publisherSite claimLink  \
# 0           en    Politifact  politifact.com       NaN
# 1           en    Politifact  politifact.com       NaN
# 2           en    Politifact  politifact.com       NaN
# 3           en    Politifact  politifact.com       NaN
# 4           en    Politifact  politifact.com       NaN
#
#                  UniformRating
# 0                        False
# 1  Half True or Out of Context
# 2                        False
# 3                  Mostly True
# 4                  Mostly True

# %% [markdown]
# Dataset is now ready

# %%
df_statement.to_csv('factcheck_politifact.csv', index=False)
